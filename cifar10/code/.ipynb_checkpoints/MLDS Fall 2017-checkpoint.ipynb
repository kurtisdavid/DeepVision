# %% [markdown]
# ### Load Images

# %%
import tensorflow as tf
from glob import glob
import numpy as np
import cv2

# %%
# function to take filenames and convert to numpy arrays
# TODO: use pickle to save the dataset instead
def convert_images(files):
    return np.asarray([cv2.imread(file) for file in files])

# %%
filenames = glob("./train/*")
filenames = sorted(filenames, key = lambda x:int(x.split('\\')[1].split('.png')[0]))

# %%
image_data = convert_images(filenames)

# %%
image_data.shape

# %%
#np.save('train.npy',image_data)

# %%
image_data = np.load('train.npy')

# %% [markdown]
# ### Load Labels

# %%
import pandas as pd

# %%
labels_df = pd.read_csv('trainLabels.csv')

# %%
labels_unique = labels_df.label.unique()

# %%
labels_unique
# Out:
# array(['frog', 'truck', 'deer', 'automobile', 'bird', 'horse', 'ship',
#        'cat', 'dog', 'airplane'], dtype=object)

# %%
# just get the id based on the filename
train_indeces = list((int(filenames[i].split('\\')[1].split('.png')[0]) for i in range(len(filenames))))

# %%
# get real labels of each
train_labels = [labels_df['label'][idx-1] for idx in train_indeces]

# %%
# convert each real label to corresponding index (0-9)
label_data = [np.where(label==labels_unique)[0][0] for label in train_labels]

# %% [markdown]
# ### Split Training/Validation

# %%
from sklearn.model_selection import train_test_split

image_train, image_val, label_train, label_val = train_test_split(image_data,label_data,test_size=0.1,random_state = 7)
image_val.shape
# Out:
# (5000, 32, 32, 3)

# %% [markdown]
# ## Training

# %% [markdown]
# For this project, we'll be utilizing [convolutional neural networks](https://en.wikipedia.org/wiki/Convolutional_neural_network). They are excellent for image problems due to their ability to capture spatial information of the pixels. A good summary can be found [here](http://cs231n.github.io/convolutional-networks/)!

# %% [markdown]
# Specifically, we implemented [Residual Networks](https://arxiv.org/abs/1512.03385), a popular architecture that uses a novel method for constructing a network.
#
# The original CNN architectures were found to have worse performance as the number of layers increase - it became increasingly difficult to backpropagate through a huge amount of layers.
#
# Residual Networks (ResNet) aims to fix this by introducing a "residual block" (seen below)

# %% [markdown]
# <img src='./resblock.png'>

# %% [markdown]
# The aim of these residual blocks is for the network to **learn whether or not convolutions in a layer are useful or not**. To do this, the output of a block will always include the identity of the inputs.
#
# If the identity transformation fit the data the most, it would be easier to zero out the weights of the convolutions in this block, rather than fitting the convolutions to an identity mapping.

# %% [markdown]
# Mathematically, let $F(x)$ be the two convolutional layers within the block. Thus our residual function $H(x)$ will just be:
#
# $$ H(x) = F(x) + x $$
#
# This can be easily backpropagated with since:
#
# $$ H'(x) = F'(x) + I $$
#
# Where $I$ is the $n x n$ identity matrix, given that $x$ as $n$ inputs.

# %% [markdown]
# ### Create Graph
#
# To actually implement this, we used [Tensorflow](https://www.tensorflow.org/).
#
# A summary of the process can be described in these steps:
#
# - Data Augmentation
# - Mean Centering Images (take mean of R,G,B channels)
# - Architecture of Actual Network:
#     - 1 Convolutional Layer
#         - kernel_size = (3,3)
#         - stride = 1
#         - num_outputs = 16
#         - Batch Norm then passed into Relu Activation
#     - 3 Residual Block Groups
#         - n residual blocks
#             - kernel_size = (3,3)
#             - stride = 1
#             - num_outputs = [16 x k,32 x k ,64 x k] (16 for first group, 32 for second, 64 for last)
#                 - k = 1 for original residual networks
#     - 1 Global Average Pooling Layer
#         - Avg Pooling, No padding
#         - kernel_size = (8,8)
#     - 1 Fully Connected Layer
#         - num_outputs = 10
# - Loss: Cross entropy + WEIGHT_DECAY * (L2 Weight Regularization)
# - Optimizer: SGD with Momentum of 0.9
#     - Initial learning rate of 0.1
#     - Decay by 1/10 at iteration 32,000 and 48,000

# %% [markdown]
# ** Data Augmentation **
# - This is an important step because it allows us to "artificially" increase our training set.
# - More data = more information the neural network can learn
# - Helps increase generalization
# - Doing two augmentations:
#     - Pad around image by 4 pixels and randomly crop a new 32x32x3 image
#     - Random horizontal flip
#
# **Changing Dimension between Residual Blocks**
# - There will be 3 Residual Blocks in the network
# - When connecting one to the next group, output channels will not match.
#     - e.g. First block group outputs 16 channels, second group outputs 32 channels. Cannot add $F(x) + x$ in first residual of second group, since $x$ has 16 channels whereas $F(x)$ will have 32.
# - Solution is to modify x so that the dimensions match:
#     - (A) You can pad 0 channels on x to match (We used this)
#     - (B) Use a 1x1 Convolution with desired output channels as a projection layer
# - Of course, we want to reduce the Width/Height dimensions going from group to group, so we also add a stride of 2 to any operation
#     - (A) Avg-pool with stride 2 before padding 0 channels
#     - (B) Just do the convolution with a stride of 2
#
#
# #### Resnet Size
# - This can be defined by a parameter $n$, which denotes how many residual blocks per group
# - We tried Resnet-20 and Resnet-32 (n=3, n=5), but can be done for more with more compute power
# - To create Wide Residual Networks (https://arxiv.org/abs/1605.07146), you just need to set the parameter k > 1.
#     - Called wide because rather than making more layers, just add more output channels in the blocks

# %% [markdown]
# ### Tensorflow Implementation

# %%
red_mean = np.mean(image_train[:,:,:,0])
green_mean = np.mean(image_train[:,:,:,1])
blue_mean = np.mean(image_train[:,:,:,2])

# %%
def residual(inputs = None, num_outputs = 16,is_training = False,projection = False, weight_decay = 1e-4):
    identity = inputs # keep output of last layer
    inputs = tf.nn.relu(tf.contrib.layers.batch_norm(inputs = inputs,is_training = is_training)) # make sure to pass through activation
    if projection:
        identity = tf.contrib.layers.avg_pool2d(inputs = identity, stride = 2, kernel_size = (2,2))
        identity = tf.pad(identity, [[0,0],[0,0],[0,0],[num_outputs//4,num_outputs//4]]) # pad with 0s to keep # filters the same
#           identity = tf.contrib.layers.conv2d(inputs = inputs, num_outputs = num_outputs, stride = 2, kernel_size = (1,1), activation_fn = None, weights_regularizer = tf.contrib.layers.l2_regularizer(weight_decay))
    conv1 = tf.contrib.layers.conv2d(inputs = inputs, num_outputs = num_outputs, stride = 2 if projection else 1, kernel_size = (3,3), activation_fn = None, weights_regularizer = tf.contrib.layers.l2_regularizer(weight_decay))
    bn1 = tf.nn.relu(tf.contrib.layers.batch_norm(inputs = conv1, is_training = is_training))
    conv2 = tf.contrib.layers.conv2d(inputs = bn1, num_outputs = num_outputs, stride = 1, kernel_size = (3,3), activation_fn = None, weights_regularizer = tf.contrib.layers.l2_regularizer(weight_decay))
    return tf.add(identity,conv2)

# %%
tf.reset_default_graph()
weight_decay = 1e-4

inputs = tf.placeholder(tf.float32, (None,32,32,3))
labels = tf.placeholder(tf.int64, (None), name='labels')
learning_rate = tf.placeholder(tf.float32, (None))
is_training = tf.placeholder(tf.bool, (None))

def image_augment(I):
    # pad 4 zeros in width and height
    I = tf.pad(I,[[4,4],[4,4],[0,0]])
    # crop new 32 x 32 image from padded image
    I = tf.random_crop(I,[32,32,3])
    # flip left/right
    I = tf.image.random_flip_left_right(I)
    return I

def normalize(I, means):
    # isolate color channels and make sure rank 3 tensors
    new_red = tf.expand_dims((I[:,:,0]-means[0])/255,-1)
    new_blue = tf.expand_dims((I[:,:,1]-means[1])/255,-1)
    new_green = tf.expand_dims((I[:,:,2]-means[2])/255,-1)
    
    return tf.concat([new_red,new_blue,new_green], axis = 2)


augmented = tf.map_fn(image_augment,inputs)
final_input = tf.identity(augmented)
whitened = tf.map_fn(lambda I: normalize(I,[red_mean,green_mean,blue_mean]), final_input)
k = 5
n_outputs = [16*k,32*k,64*k]
n = 5 # 3 -> 20 layers, 5-> 32 layers, 7->44 layers

layer1 = tf.contrib.layers.conv2d(inputs = whitened, num_outputs = 16*k, stride = 1, kernel_size = (3,3), activation_fn = None, weights_regularizer = tf.contrib.layers.l2_regularizer(weight_decay))
res_layer = residual(inputs = layer1,num_outputs = 16*k,is_training = is_training)

for i,outputs in enumerate(n_outputs):
    for j in range(n-1):
        res_layer = residual(inputs = res_layer, num_outputs = outputs, is_training = is_training)
    if (i<2):
        res_layer = residual(inputs = res_layer, num_outputs = n_outputs[i+1],is_training=is_training,projection=True)
        
res_layer = tf.nn.relu(tf.contrib.layers.batch_norm(inputs=res_layer,is_training=is_training))
global_avg_pool = tf.contrib.layers.avg_pool2d(inputs=res_layer,stride = 1, kernel_size = (8,8),padding='VALID')

fc = tf.contrib.layers.fully_connected(inputs=tf.contrib.layers.flatten(global_avg_pool),num_outputs = 10,weights_regularizer=tf.contrib.layers.l2_regularizer(weight_decay),activation_fn=None)
print(fc.shape)
output = tf.identity(fc, name='output')
    
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=output, labels=labels)) + tf.losses.get_regularization_loss()
optimizer = tf.train.MomentumOptimizer(learning_rate,0.9)

with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
    minimizer = optimizer.minimize(loss)

correct = tf.equal(tf.argmax(output, 1), labels)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# Source: CS342 with Dr. Krähenbühl
print( "Total number of variables used:", np.sum([v.get_shape().num_elements() for v in tf.trainable_variables()]))
# Out:
# (?, 10)
# Total number of variables used: 11536730

# %% [markdown]
# ### Training for 200 Epochs
#
# - Epochs are just iterations
# - Each iteration we shuffle the dataset and then feed in the images into the CNN in batches (GPU can't fit all images at once).

# %%
# Batch size
BS = 128

# Start a session
sess = tf.Session()

# Set up training
sess.run(tf.global_variables_initializer())
steps = [32000,48000]
it = 0
lr = 0.1
epoch = 0
last_acc = 0
first_div = False
while it < 64000:
    # Let's shuffle the data every epoch
    len_ = image_train.shape[0]
    np.random.seed(epoch)
    np.random.shuffle(image_train)
    np.random.seed(epoch)
    np.random.shuffle(label_train)
    # Go through the entire dataset once
    accuracy_train, loss_train = [], []
    final = 0
    for i in range(0, image_train.shape[0]-BS+1, BS):
        if it >= 64000:
            break
        if it in steps:
            lr /= 10
            first_div = True
        # Train a single batch
        batch_images, batch_labels = image_train[i:i+BS], label_train[i:i+BS]
        final = i+BS #useful for training last batch
        accuracy_, loss_, _ = sess.run([accuracy, loss, minimizer], feed_dict={inputs: batch_images, labels: batch_labels, is_training:True,learning_rate:lr})
        accuracy_train.append(accuracy_)
        loss_train.append(loss_)
        it+=1
    # train final batch
    if it >= 64000:
        break
    if it in steps:
        lr /= 10
        first_div = True
    batch_images, batch_labels = image_data[final:len_], label_data[final:len_]
    accuracy_, loss_, _ = sess.run([accuracy, loss, minimizer], feed_dict={inputs: batch_images, labels: batch_labels, is_training:True,learning_rate:lr})
    accuracy_train.append(accuracy_)
    loss_train.append(loss_)
    it+=1
    
    # compute validation results
    len_val = image_val.shape[0]
    accuracy_val, loss_val = [], []
    final = 0
    for i in range(0,len_val-BS+1,BS):
        batch_images, batch_labels = image_val[i:i+BS], label_val[i:i+BS]
        final = i+BS
        accuracy_, loss_ = sess.run([accuracy,loss],feed_dict={final_input:batch_images,labels:batch_labels,is_training:False})
        accuracy_val.append(accuracy_)
        loss_val.append(loss_)
    # test final batch
    batch_images, batch_labels = image_val[final:len_val], label_val[final:len_val]
    accuracy_, loss_ = sess.run([accuracy,loss],feed_dict={final_input:batch_images,labels:batch_labels,is_training:False})
    accuracy_val.append(accuracy_)
    loss_val.append(loss_)
    
    last_acc = np.mean(accuracy_train)
    print('[%3d] Train Accuracy: %0.3f  \t  Train Loss: %0.3f \t Val. Accuracy %0.3f \t Val. Loss %.3f '%(epoch, last_acc, np.mean(loss_train),np.mean(accuracy_val),np.mean(loss_val)))
    epoch += 1

print('[%3d] Train Accuracy: %0.3f  \t  Train Loss: %0.3f \t Val. Accuracy %0.3f \t Val. Loss %.3f '%(epoch, last_acc, np.mean(loss_train),np.mean(accuracy_val),np.mean(loss_val)))
# Out:
# [  0] Train Accuracy: 0.410  	  Train Loss: 1.871 	 Val. Accuracy 0.160 	 Val. Loss 5.729
# [  1] Train Accuracy: 0.602  	  Train Loss: 1.382 	 Val. Accuracy 0.251 	 Val. Loss 6.878
# [  2] Train Accuracy: 0.708  	  Train Loss: 1.102 	 Val. Accuracy 0.299 	 Val. Loss 6.173
# [  3] Train Accuracy: 0.766  	  Train Loss: 0.936 	 Val. Accuracy 0.295 	 Val. Loss 4.589
# [  4] Train Accuracy: 0.806  	  Train Loss: 0.823 	 Val. Accuracy 0.438 	 Val. Loss 2.882
# [  5] Train Accuracy: 0.828  	  Train Loss: 0.752 	 Val. Accuracy 0.569 	 Val. Loss 2.142
# [  6] Train Accuracy: 0.851  	  Train Loss: 0.690 	 Val. Accuracy 0.713 	 Val. Loss 1.255
# [  7] Train Accuracy: 0.863  	  Train Loss: 0.644 	 Val. Accuracy 0.711 	 Val. Loss 1.375
# [  8] Train Accuracy: 0.874  	  Train Loss: 0.602 	 Val. Accuracy 0.698 	 Val. Loss 1.466
# [  9] Train Accuracy: 0.890  	  Train Loss: 0.567 	 Val. Accuracy 0.684 	 Val. Loss 1.424
# [ 10] Train Accuracy: 0.895  	  Train Loss: 0.544 	 Val. Accuracy 0.825 	 Val. Loss 0.781
# [ 11] Train Accuracy: 0.902  	  Train Loss: 0.519 	 Val. Accuracy 0.817 	 Val. Loss 0.842
# [ 12] Train Accuracy: 0.908  	  Train Loss: 0.497 	 Val. Accuracy 0.799 	 Val. Loss 0.882
# [ 13] Train Accuracy: 0.913  	  Train Loss: 0.478 	 Val. Accuracy 0.809 	 Val. Loss 0.850
# [ 14] Train Accuracy: 0.920  	  Train Loss: 0.462 	 Val. Accuracy 0.833 	 Val. Loss 0.735
# [ 15] Train Accuracy: 0.927  	  Train Loss: 0.440 	 Val. Accuracy 0.801 	 Val. Loss 0.874
# [ 16] Train Accuracy: 0.927  	  Train Loss: 0.432 	 Val. Accuracy 0.823 	 Val. Loss 0.775
# [ 17] Train Accuracy: 0.932  	  Train Loss: 0.419 	 Val. Accuracy 0.814 	 Val. Loss 0.790
# [ 18] Train Accuracy: 0.938  	  Train Loss: 0.402 	 Val. Accuracy 0.783 	 Val. Loss 1.114
# [ 19] Train Accuracy: 0.940  	  Train Loss: 0.394 	 Val. Accuracy 0.794 	 Val. Loss 1.061
# [ 20] Train Accuracy: 0.942  	  Train Loss: 0.389 	 Val. Accuracy 0.858 	 Val. Loss 0.693
# [ 21] Train Accuracy: 0.945  	  Train Loss: 0.375 	 Val. Accuracy 0.833 	 Val. Loss 0.822
# [ 22] Train Accuracy: 0.949  	  Train Loss: 0.366 	 Val. Accuracy 0.856 	 Val. Loss 0.704
# [ 23] Train Accuracy: 0.948  	  Train Loss: 0.363 	 Val. Accuracy 0.797 	 Val. Loss 0.995
# [ 24] Train Accuracy: 0.953  	  Train Loss: 0.352 	 Val. Accuracy 0.847 	 Val. Loss 0.751
# [ 25] Train Accuracy: 0.954  	  Train Loss: 0.347 	 Val. Accuracy 0.791 	 Val. Loss 1.039
# [ 26] Train Accuracy: 0.958  	  Train Loss: 0.336 	 Val. Accuracy 0.811 	 Val. Loss 1.018
# [ 27] Train Accuracy: 0.956  	  Train Loss: 0.341 	 Val. Accuracy 0.833 	 Val. Loss 0.787
# [ 28] Train Accuracy: 0.960  	  Train Loss: 0.331 	 Val. Accuracy 0.863 	 Val. Loss 0.680
# [ 29] Train Accuracy: 0.959  	  Train Loss: 0.329 	 Val. Accuracy 0.863 	 Val. Loss 0.736
# [ 30] Train Accuracy: 0.960  	  Train Loss: 0.327 	 Val. Accuracy 0.834 	 Val. Loss 0.832
# [ 31] Train Accuracy: 0.962  	  Train Loss: 0.321 	 Val. Accuracy 0.836 	 Val. Loss 0.858
# [ 32] Train Accuracy: 0.964  	  Train Loss: 0.316 	 Val. Accuracy 0.845 	 Val. Loss 0.805
# [ 33] Train Accuracy: 0.966  	  Train Loss: 0.310 	 Val. Accuracy 0.855 	 Val. Loss 0.739
# [ 34] Train Accuracy: 0.967  	  Train Loss: 0.306 	 Val. Accuracy 0.844 	 Val. Loss 0.801
# [ 35] Train Accuracy: 0.965  	  Train Loss: 0.312 	 Val. Accuracy 0.862 	 Val. Loss 0.684
# [ 36] Train Accuracy: 0.968  	  Train Loss: 0.301 	 Val. Accuracy 0.859 	 Val. Loss 0.768
# [ 37] Train Accuracy: 0.969  	  Train Loss: 0.298 	 Val. Accuracy 0.878 	 Val. Loss 0.677
# [ 38] Train Accuracy: 0.969  	  Train Loss: 0.300 	 Val. Accuracy 0.840 	 Val. Loss 0.883
# [ 39] Train Accuracy: 0.969  	  Train Loss: 0.297 	 Val. Accuracy 0.843 	 Val. Loss 0.846
# [ 40] Train Accuracy: 0.969  	  Train Loss: 0.295 	 Val. Accuracy 0.857 	 Val. Loss 0.721
# [ 41] Train Accuracy: 0.972  	  Train Loss: 0.290 	 Val. Accuracy 0.854 	 Val. Loss 0.788
# [ 42] Train Accuracy: 0.974  	  Train Loss: 0.282 	 Val. Accuracy 0.852 	 Val. Loss 0.861
# [ 43] Train Accuracy: 0.970  	  Train Loss: 0.294 	 Val. Accuracy 0.885 	 Val. Loss 0.597
# [ 44] Train Accuracy: 0.973  	  Train Loss: 0.286 	 Val. Accuracy 0.866 	 Val. Loss 0.705
# [ 45] Train Accuracy: 0.969  	  Train Loss: 0.293 	 Val. Accuracy 0.818 	 Val. Loss 1.059
# [ 46] Train Accuracy: 0.974  	  Train Loss: 0.284 	 Val. Accuracy 0.875 	 Val. Loss 0.708
# [ 47] Train Accuracy: 0.972  	  Train Loss: 0.287 	 Val. Accuracy 0.842 	 Val. Loss 0.924
# [ 48] Train Accuracy: 0.974  	  Train Loss: 0.280 	 Val. Accuracy 0.876 	 Val. Loss 0.722
# [ 49] Train Accuracy: 0.973  	  Train Loss: 0.285 	 Val. Accuracy 0.843 	 Val. Loss 0.819
# [ 50] Train Accuracy: 0.975  	  Train Loss: 0.280 	 Val. Accuracy 0.869 	 Val. Loss 0.721
# [ 51] Train Accuracy: 0.975  	  Train Loss: 0.279 	 Val. Accuracy 0.828 	 Val. Loss 0.866
# [ 52] Train Accuracy: 0.976  	  Train Loss: 0.275 	 Val. Accuracy 0.879 	 Val. Loss 0.626
# [ 53] Train Accuracy: 0.977  	  Train Loss: 0.274 	 Val. Accuracy 0.877 	 Val. Loss 0.748
# [ 54] Train Accuracy: 0.975  	  Train Loss: 0.278 	 Val. Accuracy 0.852 	 Val. Loss 0.858
# [ 55] Train Accuracy: 0.974  	  Train Loss: 0.282 	 Val. Accuracy 0.859 	 Val. Loss 0.769
# [ 56] Train Accuracy: 0.978  	  Train Loss: 0.268 	 Val. Accuracy 0.802 	 Val. Loss 1.128
# [ 57] Train Accuracy: 0.976  	  Train Loss: 0.273 	 Val. Accuracy 0.869 	 Val. Loss 0.774
# [ 58] Train Accuracy: 0.977  	  Train Loss: 0.273 	 Val. Accuracy 0.898 	 Val. Loss 0.580
# [ 59] Train Accuracy: 0.977  	  Train Loss: 0.269 	 Val. Accuracy 0.851 	 Val. Loss 0.811
# [ 60] Train Accuracy: 0.976  	  Train Loss: 0.274 	 Val. Accuracy 0.882 	 Val. Loss 0.660
# [ 61] Train Accuracy: 0.977  	  Train Loss: 0.271 	 Val. Accuracy 0.831 	 Val. Loss 0.987
# [ 62] Train Accuracy: 0.975  	  Train Loss: 0.277 	 Val. Accuracy 0.847 	 Val. Loss 0.891
# [ 63] Train Accuracy: 0.979  	  Train Loss: 0.266 	 Val. Accuracy 0.831 	 Val. Loss 1.000
# [ 64] Train Accuracy: 0.978  	  Train Loss: 0.268 	 Val. Accuracy 0.820 	 Val. Loss 0.984
# [ 65] Train Accuracy: 0.979  	  Train Loss: 0.267 	 Val. Accuracy 0.872 	 Val. Loss 0.703
# [ 66] Train Accuracy: 0.977  	  Train Loss: 0.270 	 Val. Accuracy 0.842 	 Val. Loss 0.809
# [ 67] Train Accuracy: 0.979  	  Train Loss: 0.267 	 Val. Accuracy 0.858 	 Val. Loss 0.775
# [ 68] Train Accuracy: 0.976  	  Train Loss: 0.274 	 Val. Accuracy 0.866 	 Val. Loss 0.779
# [ 69] Train Accuracy: 0.978  	  Train Loss: 0.270 	 Val. Accuracy 0.869 	 Val. Loss 0.747
# [ 70] Train Accuracy: 0.979  	  Train Loss: 0.266 	 Val. Accuracy 0.839 	 Val. Loss 0.913
# [ 71] Train Accuracy: 0.977  	  Train Loss: 0.272 	 Val. Accuracy 0.880 	 Val. Loss 0.729
# [ 72] Train Accuracy: 0.978  	  Train Loss: 0.271 	 Val. Accuracy 0.864 	 Val. Loss 0.760
# [ 73] Train Accuracy: 0.976  	  Train Loss: 0.275 	 Val. Accuracy 0.879 	 Val. Loss 0.660
# [ 74] Train Accuracy: 0.980  	  Train Loss: 0.263 	 Val. Accuracy 0.866 	 Val. Loss 0.823
# [ 75] Train Accuracy: 0.980  	  Train Loss: 0.264 	 Val. Accuracy 0.827 	 Val. Loss 0.924
# [ 76] Train Accuracy: 0.981  	  Train Loss: 0.260 	 Val. Accuracy 0.804 	 Val. Loss 1.184
# [ 77] Train Accuracy: 0.978  	  Train Loss: 0.267 	 Val. Accuracy 0.873 	 Val. Loss 0.693
# [ 78] Train Accuracy: 0.978  	  Train Loss: 0.270 	 Val. Accuracy 0.847 	 Val. Loss 0.856
# [ 79] Train Accuracy: 0.979  	  Train Loss: 0.266 	 Val. Accuracy 0.891 	 Val. Loss 0.632
# [ 80] Train Accuracy: 0.983  	  Train Loss: 0.256 	 Val. Accuracy 0.851 	 Val. Loss 0.843
# [ 81] Train Accuracy: 0.979  	  Train Loss: 0.266 	 Val. Accuracy 0.824 	 Val. Loss 0.999
# [ 82] Train Accuracy: 0.979  	  Train Loss: 0.263 	 Val. Accuracy 0.801 	 Val. Loss 1.124
# [ 83] Train Accuracy: 0.979  	  Train Loss: 0.266 	 Val. Accuracy 0.872 	 Val. Loss 0.737
# [ 84] Train Accuracy: 0.979  	  Train Loss: 0.265 	 Val. Accuracy 0.846 	 Val. Loss 0.924
# [ 85] Train Accuracy: 0.980  	  Train Loss: 0.267 	 Val. Accuracy 0.858 	 Val. Loss 0.848
# [ 86] Train Accuracy: 0.979  	  Train Loss: 0.269 	 Val. Accuracy 0.843 	 Val. Loss 1.005
# [ 87] Train Accuracy: 0.980  	  Train Loss: 0.267 	 Val. Accuracy 0.868 	 Val. Loss 0.803
# [ 88] Train Accuracy: 0.982  	  Train Loss: 0.262 	 Val. Accuracy 0.860 	 Val. Loss 0.820
# [ 89] Train Accuracy: 0.980  	  Train Loss: 0.266 	 Val. Accuracy 0.865 	 Val. Loss 0.790
# [ 90] Train Accuracy: 0.982  	  Train Loss: 0.264 	 Val. Accuracy 0.881 	 Val. Loss 0.813
# [ 91] Train Accuracy: 0.995  	  Train Loss: 0.227 	 Val. Accuracy 0.929 	 Val. Loss 0.536
# [ 92] Train Accuracy: 0.997  	  Train Loss: 0.217 	 Val. Accuracy 0.934 	 Val. Loss 0.504
# [ 93] Train Accuracy: 0.998  	  Train Loss: 0.213 	 Val. Accuracy 0.936 	 Val. Loss 0.493
# [ 94] Train Accuracy: 0.999  	  Train Loss: 0.210 	 Val. Accuracy 0.935 	 Val. Loss 0.480
# [ 95] Train Accuracy: 0.999  	  Train Loss: 0.207 	 Val. Accuracy 0.938 	 Val. Loss 0.485
# [ 96] Train Accuracy: 0.999  	  Train Loss: 0.205 	 Val. Accuracy 0.938 	 Val. Loss 0.486
# [ 97] Train Accuracy: 0.999  	  Train Loss: 0.203 	 Val. Accuracy 0.937 	 Val. Loss 0.482
# [ 98] Train Accuracy: 0.999  	  Train Loss: 0.202 	 Val. Accuracy 0.938 	 Val. Loss 0.476
# [ 99] Train Accuracy: 1.000  	  Train Loss: 0.200 	 Val. Accuracy 0.938 	 Val. Loss 0.481
# [100] Train Accuracy: 1.000  	  Train Loss: 0.198 	 Val. Accuracy 0.940 	 Val. Loss 0.486
# [101] Train Accuracy: 1.000  	  Train Loss: 0.197 	 Val. Accuracy 0.939 	 Val. Loss 0.485
# [102] Train Accuracy: 1.000  	  Train Loss: 0.195 	 Val. Accuracy 0.939 	 Val. Loss 0.487
# [103] Train Accuracy: 1.000  	  Train Loss: 0.194 	 Val. Accuracy 0.938 	 Val. Loss 0.488
# [104] Train Accuracy: 1.000  	  Train Loss: 0.192 	 Val. Accuracy 0.937 	 Val. Loss 0.489
# [105] Train Accuracy: 1.000  	  Train Loss: 0.191 	 Val. Accuracy 0.938 	 Val. Loss 0.486
# [106] Train Accuracy: 1.000  	  Train Loss: 0.189 	 Val. Accuracy 0.938 	 Val. Loss 0.482
# [107] Train Accuracy: 1.000  	  Train Loss: 0.188 	 Val. Accuracy 0.939 	 Val. Loss 0.481
# [108] Train Accuracy: 1.000  	  Train Loss: 0.186 	 Val. Accuracy 0.937 	 Val. Loss 0.482
# [109] Train Accuracy: 1.000  	  Train Loss: 0.185 	 Val. Accuracy 0.937 	 Val. Loss 0.488
# [110] Train Accuracy: 1.000  	  Train Loss: 0.184 	 Val. Accuracy 0.938 	 Val. Loss 0.489
# [111] Train Accuracy: 1.000  	  Train Loss: 0.183 	 Val. Accuracy 0.938 	 Val. Loss 0.488
# [112] Train Accuracy: 1.000  	  Train Loss: 0.181 	 Val. Accuracy 0.937 	 Val. Loss 0.494
# [113] Train Accuracy: 1.000  	  Train Loss: 0.180 	 Val. Accuracy 0.937 	 Val. Loss 0.495
# [114] Train Accuracy: 1.000  	  Train Loss: 0.179 	 Val. Accuracy 0.938 	 Val. Loss 0.490
# [115] Train Accuracy: 1.000  	  Train Loss: 0.177 	 Val. Accuracy 0.936 	 Val. Loss 0.485
# [116] Train Accuracy: 1.000  	  Train Loss: 0.176 	 Val. Accuracy 0.938 	 Val. Loss 0.487
# [117] Train Accuracy: 1.000  	  Train Loss: 0.175 	 Val. Accuracy 0.938 	 Val. Loss 0.488
# [118] Train Accuracy: 1.000  	  Train Loss: 0.174 	 Val. Accuracy 0.938 	 Val. Loss 0.483
# [119] Train Accuracy: 1.000  	  Train Loss: 0.172 	 Val. Accuracy 0.939 	 Val. Loss 0.482
# [120] Train Accuracy: 1.000  	  Train Loss: 0.171 	 Val. Accuracy 0.939 	 Val. Loss 0.481
# [121] Train Accuracy: 1.000  	  Train Loss: 0.170 	 Val. Accuracy 0.938 	 Val. Loss 0.487
# [122] Train Accuracy: 1.000  	  Train Loss: 0.169 	 Val. Accuracy 0.939 	 Val. Loss 0.482
# [123] Train Accuracy: 1.000  	  Train Loss: 0.168 	 Val. Accuracy 0.937 	 Val. Loss 0.484
# [124] Train Accuracy: 1.000  	  Train Loss: 0.166 	 Val. Accuracy 0.940 	 Val. Loss 0.482
# [125] Train Accuracy: 1.000  	  Train Loss: 0.165 	 Val. Accuracy 0.940 	 Val. Loss 0.480
# [126] Train Accuracy: 1.000  	  Train Loss: 0.164 	 Val. Accuracy 0.939 	 Val. Loss 0.477
# [127] Train Accuracy: 1.000  	  Train Loss: 0.163 	 Val. Accuracy 0.940 	 Val. Loss 0.479
# [128] Train Accuracy: 1.000  	  Train Loss: 0.162 	 Val. Accuracy 0.940 	 Val. Loss 0.479
# [129] Train Accuracy: 1.000  	  Train Loss: 0.161 	 Val. Accuracy 0.938 	 Val. Loss 0.482
# [130] Train Accuracy: 1.000  	  Train Loss: 0.160 	 Val. Accuracy 0.938 	 Val. Loss 0.473
# [131] Train Accuracy: 1.000  	  Train Loss: 0.158 	 Val. Accuracy 0.939 	 Val. Loss 0.473
# [132] Train Accuracy: 1.000  	  Train Loss: 0.157 	 Val. Accuracy 0.938 	 Val. Loss 0.473
# [133] Train Accuracy: 1.000  	  Train Loss: 0.156 	 Val. Accuracy 0.939 	 Val. Loss 0.474
# [134] Train Accuracy: 1.000  	  Train Loss: 0.155 	 Val. Accuracy 0.939 	 Val. Loss 0.474
# [135] Train Accuracy: 1.000  	  Train Loss: 0.154 	 Val. Accuracy 0.939 	 Val. Loss 0.468
# [136] Train Accuracy: 1.000  	  Train Loss: 0.153 	 Val. Accuracy 0.939 	 Val. Loss 0.468
# [137] Train Accuracy: 1.000  	  Train Loss: 0.153 	 Val. Accuracy 0.940 	 Val. Loss 0.469
# [138] Train Accuracy: 1.000  	  Train Loss: 0.153 	 Val. Accuracy 0.940 	 Val. Loss 0.469
# [139] Train Accuracy: 1.000  	  Train Loss: 0.153 	 Val. Accuracy 0.940 	 Val. Loss 0.469
# [140] Train Accuracy: 1.000  	  Train Loss: 0.153 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [141] Train Accuracy: 1.000  	  Train Loss: 0.152 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [142] Train Accuracy: 1.000  	  Train Loss: 0.152 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [143] Train Accuracy: 1.000  	  Train Loss: 0.152 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [144] Train Accuracy: 1.000  	  Train Loss: 0.152 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [145] Train Accuracy: 1.000  	  Train Loss: 0.152 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [146] Train Accuracy: 1.000  	  Train Loss: 0.152 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [147] Train Accuracy: 1.000  	  Train Loss: 0.152 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [148] Train Accuracy: 1.000  	  Train Loss: 0.152 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [149] Train Accuracy: 1.000  	  Train Loss: 0.152 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [150] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.939 	 Val. Loss 0.468
# [151] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [152] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.939 	 Val. Loss 0.468
# [153] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.939 	 Val. Loss 0.468
# [154] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.940 	 Val. Loss 0.467
# [155] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.939 	 Val. Loss 0.467
# [156] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.940 	 Val. Loss 0.467
# [157] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.940 	 Val. Loss 0.467
# [158] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.939 	 Val. Loss 0.466
# [159] Train Accuracy: 1.000  	  Train Loss: 0.151 	 Val. Accuracy 0.939 	 Val. Loss 0.467
# [160] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.940 	 Val. Loss 0.466
# [161] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.939 	 Val. Loss 0.467
# [162] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.939 	 Val. Loss 0.466
# [163] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.939 	 Val. Loss 0.466
# [164] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.940 	 Val. Loss 0.466
# [165] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.940 	 Val. Loss 0.466
# [166] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.940 	 Val. Loss 0.466
# [167] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.939 	 Val. Loss 0.465
# [168] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.939 	 Val. Loss 0.464
# [169] Train Accuracy: 1.000  	  Train Loss: 0.150 	 Val. Accuracy 0.939 	 Val. Loss 0.464
# [170] Train Accuracy: 1.000  	  Train Loss: 0.149 	 Val. Accuracy 0.940 	 Val. Loss 0.464
# [171] Train Accuracy: 1.000  	  Train Loss: 0.149 	 Val. Accuracy 0.940 	 Val. Loss 0.464
# [172] Train Accuracy: 1.000  	  Train Loss: 0.149 	 Val. Accuracy 0.940 	 Val. Loss 0.464
# [173] Train Accuracy: 1.000  	  Train Loss: 0.149 	 Val. Accuracy 0.939 	 Val. Loss 0.464
# [174] Train Accuracy: 1.000  	  Train Loss: 0.149 	 Val. Accuracy 0.940 	 Val. Loss 0.464
# [175] Train Accuracy: 1.000  	  Train Loss: 0.149 	 Val. Accuracy 0.939 	 Val. Loss 0.464
# [176] Train Accuracy: 1.000  	  Train Loss: 0.149 	 Val. Accuracy 0.940 	 Val. Loss 0.464
# [177] Train Accuracy: 1.000  	  Train Loss: 0.149 	 Val. Accuracy 0.940 	 Val. Loss 0.464
# [178] Train Accuracy: 1.000  	  Train Loss: 0.148 	 Val. Accuracy 0.940 	 Val. Loss 0.464
# [179] Train Accuracy: 1.000  	  Train Loss: 0.148 	 Val. Accuracy 0.940 	 Val. Loss 0.464
# [180] Train Accuracy: 1.000  	  Train Loss: 0.148 	 Val. Accuracy 0.939 	 Val. Loss 0.464
# [181] Train Accuracy: 1.000  	  Train Loss: 0.148 	 Val. Accuracy 0.939 	 Val. Loss 0.464

# %% [markdown]
# ### Resnet 32 - Wide k = 4

# %%
# Batch size
BS = 128

# Start a session
sess = tf.Session()

# Set up training
sess.run(tf.global_variables_initializer())
steps = [32000,48000]
it = 0
lr = 0.1
epoch = 0
last_acc = 0
first_div = False
while it < 64000:
    # Let's shuffle the data every epoch
    len_ = image_train.shape[0]
    np.random.seed(epoch)
    np.random.shuffle(image_train)
    np.random.seed(epoch)
    np.random.shuffle(label_train)
    # Go through the entire dataset once
    accuracy_train, loss_train = [], []
    final = 0
    for i in range(0, image_train.shape[0]-BS+1, BS):
        if it >= 64000:
            break
        if it in steps:
            lr /= 10
            first_div = True
        # Train a single batch
        batch_images, batch_labels = image_train[i:i+BS], label_train[i:i+BS]
        final = i+BS #useful for training last batch
        accuracy_, loss_, _ = sess.run([accuracy, loss, minimizer], feed_dict={inputs: batch_images, labels: batch_labels, is_training:True,learning_rate:lr})
        accuracy_train.append(accuracy_)
        loss_train.append(loss_)
        it+=1
    # train final batch
    if it >= 64000:
        break
    if it in steps:
        lr /= 10
        first_div = True
    batch_images, batch_labels = image_data[final:len_], label_data[final:len_]
    accuracy_, loss_, _ = sess.run([accuracy, loss, minimizer], feed_dict={inputs: batch_images, labels: batch_labels, is_training:True,learning_rate:lr})
    accuracy_train.append(accuracy_)
    loss_train.append(loss_)
    it+=1
    
    # compute validation results
    len_val = image_val.shape[0]
    accuracy_val, loss_val = [], []
    final = 0
    for i in range(0,len_val-BS+1,BS):
        batch_images, batch_labels = image_val[i:i+BS], label_val[i:i+BS]
        final = i+BS
        accuracy_, loss_ = sess.run([accuracy,loss],feed_dict={final_input:batch_images,labels:batch_labels,is_training:False})
        accuracy_val.append(accuracy_)
        loss_val.append(loss_)
    # test final batch
    batch_images, batch_labels = image_val[final:len_val], label_val[final:len_val]
    accuracy_, loss_ = sess.run([accuracy,loss],feed_dict={final_input:batch_images,labels:batch_labels,is_training:False})
    accuracy_val.append(accuracy_)
    loss_val.append(loss_)
    
    last_acc = np.mean(accuracy_train)
    print('[%3d] Train Accuracy: %0.3f  \t  Train Loss: %0.3f \t Val. Accuracy %0.3f \t Val. Loss %.3f '%(epoch, last_acc, np.mean(loss_train),np.mean(accuracy_val),np.mean(loss_val)))
    epoch += 1

print('[%3d] Train Accuracy: %0.3f  \t  Train Loss: %0.3f \t Val. Accuracy %0.3f \t Val. Loss %.3f '%(epoch, last_acc, np.mean(loss_train),np.mean(accuracy_val),np.mean(loss_val)))
# Out:
# [  0] Train Accuracy: 0.412  	  Train Loss: 1.813 	 Val. Accuracy 0.139 	 Val. Loss 5.828
# [  1] Train Accuracy: 0.604  	  Train Loss: 1.335 	 Val. Accuracy 0.188 	 Val. Loss 10.248
# [  2] Train Accuracy: 0.705  	  Train Loss: 1.062 	 Val. Accuracy 0.401 	 Val. Loss 3.995
# [  3] Train Accuracy: 0.764  	  Train Loss: 0.894 	 Val. Accuracy 0.447 	 Val. Loss 3.019
# [  4] Train Accuracy: 0.800  	  Train Loss: 0.792 	 Val. Accuracy 0.562 	 Val. Loss 2.355
# [  5] Train Accuracy: 0.827  	  Train Loss: 0.718 	 Val. Accuracy 0.730 	 Val. Loss 1.124
# [  6] Train Accuracy: 0.847  	  Train Loss: 0.662 	 Val. Accuracy 0.691 	 Val. Loss 1.530
# [  7] Train Accuracy: 0.861  	  Train Loss: 0.618 	 Val. Accuracy 0.648 	 Val. Loss 1.712
# [  8] Train Accuracy: 0.872  	  Train Loss: 0.585 	 Val. Accuracy 0.788 	 Val. Loss 0.948
# [  9] Train Accuracy: 0.883  	  Train Loss: 0.552 	 Val. Accuracy 0.679 	 Val. Loss 1.371
# [ 10] Train Accuracy: 0.892  	  Train Loss: 0.526 	 Val. Accuracy 0.812 	 Val. Loss 0.773
# [ 11] Train Accuracy: 0.900  	  Train Loss: 0.501 	 Val. Accuracy 0.800 	 Val. Loss 0.855
# [ 12] Train Accuracy: 0.906  	  Train Loss: 0.483 	 Val. Accuracy 0.762 	 Val. Loss 1.077
# [ 13] Train Accuracy: 0.910  	  Train Loss: 0.466 	 Val. Accuracy 0.800 	 Val. Loss 0.826
# [ 14] Train Accuracy: 0.918  	  Train Loss: 0.444 	 Val. Accuracy 0.802 	 Val. Loss 0.853
# [ 15] Train Accuracy: 0.921  	  Train Loss: 0.433 	 Val. Accuracy 0.708 	 Val. Loss 1.341
# [ 16] Train Accuracy: 0.926  	  Train Loss: 0.422 	 Val. Accuracy 0.783 	 Val. Loss 0.929
# [ 17] Train Accuracy: 0.931  	  Train Loss: 0.407 	 Val. Accuracy 0.853 	 Val. Loss 0.682
# [ 18] Train Accuracy: 0.933  	  Train Loss: 0.397 	 Val. Accuracy 0.766 	 Val. Loss 1.127
# [ 19] Train Accuracy: 0.937  	  Train Loss: 0.386 	 Val. Accuracy 0.852 	 Val. Loss 0.648
# [ 20] Train Accuracy: 0.940  	  Train Loss: 0.380 	 Val. Accuracy 0.853 	 Val. Loss 0.698
# [ 21] Train Accuracy: 0.943  	  Train Loss: 0.369 	 Val. Accuracy 0.775 	 Val. Loss 1.110
# [ 22] Train Accuracy: 0.945  	  Train Loss: 0.364 	 Val. Accuracy 0.822 	 Val. Loss 0.825
# [ 23] Train Accuracy: 0.947  	  Train Loss: 0.356 	 Val. Accuracy 0.844 	 Val. Loss 0.729
# [ 24] Train Accuracy: 0.951  	  Train Loss: 0.350 	 Val. Accuracy 0.868 	 Val. Loss 0.633
# [ 25] Train Accuracy: 0.952  	  Train Loss: 0.346 	 Val. Accuracy 0.851 	 Val. Loss 0.728
# [ 26] Train Accuracy: 0.953  	  Train Loss: 0.339 	 Val. Accuracy 0.816 	 Val. Loss 0.807
# [ 27] Train Accuracy: 0.956  	  Train Loss: 0.331 	 Val. Accuracy 0.826 	 Val. Loss 0.968
# [ 28] Train Accuracy: 0.958  	  Train Loss: 0.327 	 Val. Accuracy 0.855 	 Val. Loss 0.719
# [ 29] Train Accuracy: 0.956  	  Train Loss: 0.330 	 Val. Accuracy 0.847 	 Val. Loss 0.717
# [ 30] Train Accuracy: 0.959  	  Train Loss: 0.323 	 Val. Accuracy 0.843 	 Val. Loss 0.730
# [ 31] Train Accuracy: 0.960  	  Train Loss: 0.322 	 Val. Accuracy 0.828 	 Val. Loss 0.801
# [ 32] Train Accuracy: 0.960  	  Train Loss: 0.320 	 Val. Accuracy 0.838 	 Val. Loss 0.812
# [ 33] Train Accuracy: 0.963  	  Train Loss: 0.310 	 Val. Accuracy 0.856 	 Val. Loss 0.687
# [ 34] Train Accuracy: 0.966  	  Train Loss: 0.305 	 Val. Accuracy 0.853 	 Val. Loss 0.771
# [ 35] Train Accuracy: 0.966  	  Train Loss: 0.305 	 Val. Accuracy 0.817 	 Val. Loss 0.919
# [ 36] Train Accuracy: 0.968  	  Train Loss: 0.300 	 Val. Accuracy 0.842 	 Val. Loss 0.807
# [ 37] Train Accuracy: 0.964  	  Train Loss: 0.307 	 Val. Accuracy 0.855 	 Val. Loss 0.765
# [ 38] Train Accuracy: 0.968  	  Train Loss: 0.303 	 Val. Accuracy 0.827 	 Val. Loss 0.842
# [ 39] Train Accuracy: 0.966  	  Train Loss: 0.303 	 Val. Accuracy 0.858 	 Val. Loss 0.728
# [ 40] Train Accuracy: 0.968  	  Train Loss: 0.301 	 Val. Accuracy 0.879 	 Val. Loss 0.625
# [ 41] Train Accuracy: 0.969  	  Train Loss: 0.298 	 Val. Accuracy 0.873 	 Val. Loss 0.625
# [ 42] Train Accuracy: 0.970  	  Train Loss: 0.291 	 Val. Accuracy 0.841 	 Val. Loss 0.780
# [ 43] Train Accuracy: 0.969  	  Train Loss: 0.296 	 Val. Accuracy 0.843 	 Val. Loss 0.804
# [ 44] Train Accuracy: 0.972  	  Train Loss: 0.287 	 Val. Accuracy 0.863 	 Val. Loss 0.748
# [ 45] Train Accuracy: 0.970  	  Train Loss: 0.295 	 Val. Accuracy 0.863 	 Val. Loss 0.739
# [ 46] Train Accuracy: 0.970  	  Train Loss: 0.293 	 Val. Accuracy 0.838 	 Val. Loss 0.834
# [ 47] Train Accuracy: 0.970  	  Train Loss: 0.293 	 Val. Accuracy 0.827 	 Val. Loss 1.009
# [ 48] Train Accuracy: 0.975  	  Train Loss: 0.283 	 Val. Accuracy 0.850 	 Val. Loss 0.796
# [ 49] Train Accuracy: 0.972  	  Train Loss: 0.287 	 Val. Accuracy 0.885 	 Val. Loss 0.645
# [ 50] Train Accuracy: 0.971  	  Train Loss: 0.291 	 Val. Accuracy 0.829 	 Val. Loss 1.008
# [ 51] Train Accuracy: 0.973  	  Train Loss: 0.287 	 Val. Accuracy 0.829 	 Val. Loss 0.891
# [ 52] Train Accuracy: 0.974  	  Train Loss: 0.282 	 Val. Accuracy 0.862 	 Val. Loss 0.732
# [ 53] Train Accuracy: 0.975  	  Train Loss: 0.281 	 Val. Accuracy 0.853 	 Val. Loss 0.856
# [ 54] Train Accuracy: 0.973  	  Train Loss: 0.286 	 Val. Accuracy 0.853 	 Val. Loss 0.897
# [ 55] Train Accuracy: 0.975  	  Train Loss: 0.283 	 Val. Accuracy 0.876 	 Val. Loss 0.655
# [ 56] Train Accuracy: 0.975  	  Train Loss: 0.283 	 Val. Accuracy 0.879 	 Val. Loss 0.727
# [ 57] Train Accuracy: 0.975  	  Train Loss: 0.282 	 Val. Accuracy 0.882 	 Val. Loss 0.674
# [ 58] Train Accuracy: 0.977  	  Train Loss: 0.275 	 Val. Accuracy 0.880 	 Val. Loss 0.639
# [ 59] Train Accuracy: 0.976  	  Train Loss: 0.278 	 Val. Accuracy 0.889 	 Val. Loss 0.644
# [ 60] Train Accuracy: 0.973  	  Train Loss: 0.289 	 Val. Accuracy 0.865 	 Val. Loss 0.781
# [ 61] Train Accuracy: 0.977  	  Train Loss: 0.275 	 Val. Accuracy 0.858 	 Val. Loss 0.807
# [ 62] Train Accuracy: 0.976  	  Train Loss: 0.279 	 Val. Accuracy 0.873 	 Val. Loss 0.649
# [ 63] Train Accuracy: 0.977  	  Train Loss: 0.276 	 Val. Accuracy 0.856 	 Val. Loss 0.872
# [ 64] Train Accuracy: 0.977  	  Train Loss: 0.274 	 Val. Accuracy 0.890 	 Val. Loss 0.632
# [ 65] Train Accuracy: 0.976  	  Train Loss: 0.278 	 Val. Accuracy 0.861 	 Val. Loss 0.756
# [ 66] Train Accuracy: 0.976  	  Train Loss: 0.279 	 Val. Accuracy 0.871 	 Val. Loss 0.732
# [ 67] Train Accuracy: 0.976  	  Train Loss: 0.281 	 Val. Accuracy 0.841 	 Val. Loss 0.876
# [ 68] Train Accuracy: 0.975  	  Train Loss: 0.282 	 Val. Accuracy 0.828 	 Val. Loss 0.983
# [ 69] Train Accuracy: 0.978  	  Train Loss: 0.277 	 Val. Accuracy 0.867 	 Val. Loss 0.773
# [ 70] Train Accuracy: 0.976  	  Train Loss: 0.279 	 Val. Accuracy 0.871 	 Val. Loss 0.724
# [ 71] Train Accuracy: 0.977  	  Train Loss: 0.281 	 Val. Accuracy 0.880 	 Val. Loss 0.718
# [ 72] Train Accuracy: 0.978  	  Train Loss: 0.274 	 Val. Accuracy 0.847 	 Val. Loss 0.834
# [ 73] Train Accuracy: 0.977  	  Train Loss: 0.282 	 Val. Accuracy 0.864 	 Val. Loss 0.838
# [ 74] Train Accuracy: 0.978  	  Train Loss: 0.276 	 Val. Accuracy 0.868 	 Val. Loss 0.714
# [ 75] Train Accuracy: 0.978  	  Train Loss: 0.277 	 Val. Accuracy 0.871 	 Val. Loss 0.747
# [ 76] Train Accuracy: 0.979  	  Train Loss: 0.272 	 Val. Accuracy 0.845 	 Val. Loss 0.896
# [ 77] Train Accuracy: 0.978  	  Train Loss: 0.276 	 Val. Accuracy 0.866 	 Val. Loss 0.731
# [ 78] Train Accuracy: 0.979  	  Train Loss: 0.273 	 Val. Accuracy 0.853 	 Val. Loss 0.812
# [ 79] Train Accuracy: 0.977  	  Train Loss: 0.280 	 Val. Accuracy 0.884 	 Val. Loss 0.692
# [ 80] Train Accuracy: 0.980  	  Train Loss: 0.274 	 Val. Accuracy 0.832 	 Val. Loss 1.074
# [ 81] Train Accuracy: 0.978  	  Train Loss: 0.276 	 Val. Accuracy 0.876 	 Val. Loss 0.736
# [ 82] Train Accuracy: 0.976  	  Train Loss: 0.282 	 Val. Accuracy 0.855 	 Val. Loss 0.863
# [ 83] Train Accuracy: 0.978  	  Train Loss: 0.278 	 Val. Accuracy 0.881 	 Val. Loss 0.688
# [ 84] Train Accuracy: 0.979  	  Train Loss: 0.276 	 Val. Accuracy 0.853 	 Val. Loss 0.855
# [ 85] Train Accuracy: 0.978  	  Train Loss: 0.279 	 Val. Accuracy 0.896 	 Val. Loss 0.663
# [ 86] Train Accuracy: 0.978  	  Train Loss: 0.280 	 Val. Accuracy 0.851 	 Val. Loss 0.865
# [ 87] Train Accuracy: 0.980  	  Train Loss: 0.274 	 Val. Accuracy 0.865 	 Val. Loss 0.776
# [ 88] Train Accuracy: 0.979  	  Train Loss: 0.278 	 Val. Accuracy 0.838 	 Val. Loss 0.901
# [ 89] Train Accuracy: 0.980  	  Train Loss: 0.272 	 Val. Accuracy 0.874 	 Val. Loss 0.680
# [ 90] Train Accuracy: 0.978  	  Train Loss: 0.280 	 Val. Accuracy 0.871 	 Val. Loss 0.770
# [ 91] Train Accuracy: 0.991  	  Train Loss: 0.242 	 Val. Accuracy 0.925 	 Val. Loss 0.516
# [ 92] Train Accuracy: 0.997  	  Train Loss: 0.227 	 Val. Accuracy 0.932 	 Val. Loss 0.490
# [ 93] Train Accuracy: 0.998  	  Train Loss: 0.222 	 Val. Accuracy 0.931 	 Val. Loss 0.479
# [ 94] Train Accuracy: 0.998  	  Train Loss: 0.219 	 Val. Accuracy 0.937 	 Val. Loss 0.465
# [ 95] Train Accuracy: 0.999  	  Train Loss: 0.217 	 Val. Accuracy 0.935 	 Val. Loss 0.467
# [ 96] Train Accuracy: 0.999  	  Train Loss: 0.214 	 Val. Accuracy 0.938 	 Val. Loss 0.465
# [ 97] Train Accuracy: 0.999  	  Train Loss: 0.213 	 Val. Accuracy 0.936 	 Val. Loss 0.465
# [ 98] Train Accuracy: 0.999  	  Train Loss: 0.210 	 Val. Accuracy 0.938 	 Val. Loss 0.464
# [ 99] Train Accuracy: 0.999  	  Train Loss: 0.209 	 Val. Accuracy 0.939 	 Val. Loss 0.469
# [100] Train Accuracy: 0.999  	  Train Loss: 0.207 	 Val. Accuracy 0.939 	 Val. Loss 0.473
# [101] Train Accuracy: 0.999  	  Train Loss: 0.205 	 Val. Accuracy 0.938 	 Val. Loss 0.470
# [102] Train Accuracy: 0.999  	  Train Loss: 0.203 	 Val. Accuracy 0.938 	 Val. Loss 0.471
# [103] Train Accuracy: 1.000  	  Train Loss: 0.201 	 Val. Accuracy 0.938 	 Val. Loss 0.468
# [104] Train Accuracy: 1.000  	  Train Loss: 0.200 	 Val. Accuracy 0.938 	 Val. Loss 0.474
# [105] Train Accuracy: 1.000  	  Train Loss: 0.199 	 Val. Accuracy 0.937 	 Val. Loss 0.477
# [106] Train Accuracy: 1.000  	  Train Loss: 0.197 	 Val. Accuracy 0.939 	 Val. Loss 0.473
# [107] Train Accuracy: 1.000  	  Train Loss: 0.196 	 Val. Accuracy 0.938 	 Val. Loss 0.479
# [108] Train Accuracy: 1.000  	  Train Loss: 0.194 	 Val. Accuracy 0.939 	 Val. Loss 0.470
# [109] Train Accuracy: 1.000  	  Train Loss: 0.193 	 Val. Accuracy 0.940 	 Val. Loss 0.468
# [110] Train Accuracy: 1.000  	  Train Loss: 0.191 	 Val. Accuracy 0.941 	 Val. Loss 0.466
# [111] Train Accuracy: 1.000  	  Train Loss: 0.190 	 Val. Accuracy 0.941 	 Val. Loss 0.466
# [112] Train Accuracy: 1.000  	  Train Loss: 0.189 	 Val. Accuracy 0.941 	 Val. Loss 0.464
# [113] Train Accuracy: 1.000  	  Train Loss: 0.187 	 Val. Accuracy 0.940 	 Val. Loss 0.460
# [114] Train Accuracy: 1.000  	  Train Loss: 0.186 	 Val. Accuracy 0.941 	 Val. Loss 0.461
# [115] Train Accuracy: 1.000  	  Train Loss: 0.185 	 Val. Accuracy 0.941 	 Val. Loss 0.466
# [116] Train Accuracy: 1.000  	  Train Loss: 0.183 	 Val. Accuracy 0.940 	 Val. Loss 0.456
# [117] Train Accuracy: 1.000  	  Train Loss: 0.182 	 Val. Accuracy 0.938 	 Val. Loss 0.465
# [118] Train Accuracy: 1.000  	  Train Loss: 0.181 	 Val. Accuracy 0.939 	 Val. Loss 0.469
# [119] Train Accuracy: 1.000  	  Train Loss: 0.179 	 Val. Accuracy 0.939 	 Val. Loss 0.463
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-b581d0159c5a> in <module>()
#      32         batch_images, batch_labels = image_train[i:i+BS], label_train[i:i+BS]
#      33         final = i+BS #useful for training last batch
# ---> 34         accuracy_, loss_, _ = sess.run([accuracy, loss, minimizer], feed_dict={inputs: batch_images, labels: batch_labels, is_training:True,learning_rate:lr})
#      35         accuracy_train.append(accuracy_)
#      36         loss_train.append(loss_)
#
# c:\users\kurti\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\kurti\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# c:\users\kurti\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# c:\users\kurti\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# c:\users\kurti\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Resnet 32

# %%
# Batch size
BS = 128

# Start a session
sess = tf.Session()

# Set up training
sess.run(tf.global_variables_initializer())
steps = [32000,48000]
it = 0
lr = 0.1
epoch = 0
last_acc = 0
first_div = False
while it < 64000:
    # Let's shuffle the data every epoch
    len_ = image_train.shape[0]
    np.random.seed(epoch)
    np.random.shuffle(image_train)
    np.random.seed(epoch)
    np.random.shuffle(label_train)
    # Go through the entire dataset once
    accuracy_train, loss_train = [], []
    final = 0
    for i in range(0, image_train.shape[0]-BS+1, BS):
        if it >= 64000:
            break
        if it in steps:
            lr /= 10
            first_div = True
        # Train a single batch
        batch_images, batch_labels = image_train[i:i+BS], label_train[i:i+BS]
        final = i+BS #useful for training last batch
        accuracy_, loss_, _ = sess.run([accuracy, loss, minimizer], feed_dict={inputs: batch_images, labels: batch_labels, is_training:True,learning_rate:lr})
        accuracy_train.append(accuracy_)
        loss_train.append(loss_)
        it+=1
    # train final batch
    if it >= 64000:
        break
    if it in steps:
        lr /= 10
        first_div = True
    batch_images, batch_labels = image_data[final:len_], label_data[final:len_]
    accuracy_, loss_, _ = sess.run([accuracy, loss, minimizer], feed_dict={inputs: batch_images, labels: batch_labels, is_training:True,learning_rate:lr})
    accuracy_train.append(accuracy_)
    loss_train.append(loss_)
    it+=1
    
    # compute validation results
    len_val = image_val.shape[0]
    accuracy_val, loss_val = [], []
    final = 0
    for i in range(0,len_val-BS+1,BS):
        batch_images, batch_labels = image_val[i:i+BS], label_val[i:i+BS]
        final = i+BS
        accuracy_, loss_ = sess.run([accuracy,loss],feed_dict={final_input:batch_images,labels:batch_labels,is_training:False})
        accuracy_val.append(accuracy_)
        loss_val.append(loss_)
    # test final batch
    batch_images, batch_labels = image_val[final:len_val], label_val[final:len_val]
    accuracy_, loss_ = sess.run([accuracy,loss],feed_dict={final_input:batch_images,labels:batch_labels,is_training:False})
    accuracy_val.append(accuracy_)
    loss_val.append(loss_)
    
    last_acc = np.mean(accuracy_train)
    print('[%3d] Train Accuracy: %0.3f  \t  Train Loss: %0.3f \t Val. Accuracy %0.3f \t Val. Loss %.3f '%(epoch, last_acc, np.mean(loss_train),np.mean(accuracy_val),np.mean(loss_val)))
    epoch += 1

print('[%3d] Train Accuracy: %0.3f  \t  Train Loss: %0.3f \t Val. Accuracy %0.3f \t Val. Loss %.3f '%(epoch, last_acc, np.mean(loss_train),np.mean(accuracy_val),np.mean(loss_val)))
# Out:
# [  0] Train Accuracy: 0.386  	  Train Loss: 1.714 	 Val. Accuracy 0.134 	 Val. Loss 27.767
# [  1] Train Accuracy: 0.571  	  Train Loss: 1.262 	 Val. Accuracy 0.110 	 Val. Loss 62.848
# [  2] Train Accuracy: 0.674  	  Train Loss: 1.005 	 Val. Accuracy 0.124 	 Val. Loss 25.368
# [  3] Train Accuracy: 0.730  	  Train Loss: 0.862 	 Val. Accuracy 0.317 	 Val. Loss 5.826
# [  4] Train Accuracy: 0.767  	  Train Loss: 0.768 	 Val. Accuracy 0.316 	 Val. Loss 7.101
# [  5] Train Accuracy: 0.789  	  Train Loss: 0.709 	 Val. Accuracy 0.538 	 Val. Loss 2.266
# [  6] Train Accuracy: 0.805  	  Train Loss: 0.673 	 Val. Accuracy 0.541 	 Val. Loss 2.290
# [  7] Train Accuracy: 0.818  	  Train Loss: 0.637 	 Val. Accuracy 0.639 	 Val. Loss 1.494
# [  8] Train Accuracy: 0.832  	  Train Loss: 0.611 	 Val. Accuracy 0.755 	 Val. Loss 0.912
# [  9] Train Accuracy: 0.838  	  Train Loss: 0.587 	 Val. Accuracy 0.644 	 Val. Loss 1.529
# [ 10] Train Accuracy: 0.845  	  Train Loss: 0.576 	 Val. Accuracy 0.702 	 Val. Loss 1.155
# [ 11] Train Accuracy: 0.855  	  Train Loss: 0.553 	 Val. Accuracy 0.648 	 Val. Loss 1.556
# [ 12] Train Accuracy: 0.858  	  Train Loss: 0.544 	 Val. Accuracy 0.718 	 Val. Loss 1.100
# [ 13] Train Accuracy: 0.864  	  Train Loss: 0.528 	 Val. Accuracy 0.715 	 Val. Loss 1.095
# [ 14] Train Accuracy: 0.869  	  Train Loss: 0.518 	 Val. Accuracy 0.670 	 Val. Loss 1.405
# [ 15] Train Accuracy: 0.874  	  Train Loss: 0.509 	 Val. Accuracy 0.757 	 Val. Loss 0.986
# [ 16] Train Accuracy: 0.875  	  Train Loss: 0.504 	 Val. Accuracy 0.655 	 Val. Loss 1.249
# [ 17] Train Accuracy: 0.879  	  Train Loss: 0.496 	 Val. Accuracy 0.787 	 Val. Loss 0.792
# [ 18] Train Accuracy: 0.883  	  Train Loss: 0.485 	 Val. Accuracy 0.811 	 Val. Loss 0.736
# [ 19] Train Accuracy: 0.886  	  Train Loss: 0.478 	 Val. Accuracy 0.788 	 Val. Loss 0.832
# [ 20] Train Accuracy: 0.889  	  Train Loss: 0.473 	 Val. Accuracy 0.770 	 Val. Loss 0.885
# [ 21] Train Accuracy: 0.892  	  Train Loss: 0.467 	 Val. Accuracy 0.725 	 Val. Loss 1.077
# [ 22] Train Accuracy: 0.895  	  Train Loss: 0.461 	 Val. Accuracy 0.690 	 Val. Loss 1.242
# [ 23] Train Accuracy: 0.899  	  Train Loss: 0.457 	 Val. Accuracy 0.800 	 Val. Loss 0.771
# [ 24] Train Accuracy: 0.898  	  Train Loss: 0.455 	 Val. Accuracy 0.768 	 Val. Loss 0.961
# [ 25] Train Accuracy: 0.901  	  Train Loss: 0.446 	 Val. Accuracy 0.671 	 Val. Loss 1.262
# [ 26] Train Accuracy: 0.902  	  Train Loss: 0.447 	 Val. Accuracy 0.812 	 Val. Loss 0.768
# [ 27] Train Accuracy: 0.904  	  Train Loss: 0.444 	 Val. Accuracy 0.729 	 Val. Loss 1.096
# [ 28] Train Accuracy: 0.904  	  Train Loss: 0.442 	 Val. Accuracy 0.799 	 Val. Loss 0.846
# [ 29] Train Accuracy: 0.909  	  Train Loss: 0.435 	 Val. Accuracy 0.689 	 Val. Loss 1.373
# [ 30] Train Accuracy: 0.908  	  Train Loss: 0.440 	 Val. Accuracy 0.719 	 Val. Loss 1.201
# [ 31] Train Accuracy: 0.912  	  Train Loss: 0.426 	 Val. Accuracy 0.809 	 Val. Loss 0.777
# [ 32] Train Accuracy: 0.911  	  Train Loss: 0.431 	 Val. Accuracy 0.782 	 Val. Loss 0.923
# [ 33] Train Accuracy: 0.916  	  Train Loss: 0.420 	 Val. Accuracy 0.812 	 Val. Loss 0.727
# [ 34] Train Accuracy: 0.914  	  Train Loss: 0.426 	 Val. Accuracy 0.819 	 Val. Loss 0.756
# [ 35] Train Accuracy: 0.915  	  Train Loss: 0.421 	 Val. Accuracy 0.814 	 Val. Loss 0.775
# [ 36] Train Accuracy: 0.918  	  Train Loss: 0.418 	 Val. Accuracy 0.808 	 Val. Loss 0.887
# [ 37] Train Accuracy: 0.918  	  Train Loss: 0.415 	 Val. Accuracy 0.803 	 Val. Loss 0.911
# [ 38] Train Accuracy: 0.919  	  Train Loss: 0.418 	 Val. Accuracy 0.779 	 Val. Loss 0.971
# [ 39] Train Accuracy: 0.920  	  Train Loss: 0.416 	 Val. Accuracy 0.809 	 Val. Loss 0.789
# [ 40] Train Accuracy: 0.920  	  Train Loss: 0.410 	 Val. Accuracy 0.807 	 Val. Loss 0.888
# [ 41] Train Accuracy: 0.921  	  Train Loss: 0.413 	 Val. Accuracy 0.792 	 Val. Loss 0.873
# [ 42] Train Accuracy: 0.922  	  Train Loss: 0.409 	 Val. Accuracy 0.815 	 Val. Loss 0.770
# [ 43] Train Accuracy: 0.924  	  Train Loss: 0.407 	 Val. Accuracy 0.770 	 Val. Loss 1.080
# [ 44] Train Accuracy: 0.925  	  Train Loss: 0.406 	 Val. Accuracy 0.803 	 Val. Loss 0.871
# [ 45] Train Accuracy: 0.924  	  Train Loss: 0.404 	 Val. Accuracy 0.786 	 Val. Loss 0.905
# [ 46] Train Accuracy: 0.924  	  Train Loss: 0.405 	 Val. Accuracy 0.808 	 Val. Loss 0.837
# [ 47] Train Accuracy: 0.927  	  Train Loss: 0.402 	 Val. Accuracy 0.806 	 Val. Loss 0.831
# [ 48] Train Accuracy: 0.927  	  Train Loss: 0.400 	 Val. Accuracy 0.793 	 Val. Loss 0.924
# [ 49] Train Accuracy: 0.926  	  Train Loss: 0.406 	 Val. Accuracy 0.807 	 Val. Loss 0.814
# [ 50] Train Accuracy: 0.929  	  Train Loss: 0.397 	 Val. Accuracy 0.756 	 Val. Loss 1.082
# [ 51] Train Accuracy: 0.932  	  Train Loss: 0.394 	 Val. Accuracy 0.823 	 Val. Loss 0.841
# [ 52] Train Accuracy: 0.929  	  Train Loss: 0.399 	 Val. Accuracy 0.800 	 Val. Loss 0.949
# [ 53] Train Accuracy: 0.932  	  Train Loss: 0.393 	 Val. Accuracy 0.820 	 Val. Loss 0.806
# [ 54] Train Accuracy: 0.930  	  Train Loss: 0.397 	 Val. Accuracy 0.840 	 Val. Loss 0.744
# [ 55] Train Accuracy: 0.932  	  Train Loss: 0.390 	 Val. Accuracy 0.773 	 Val. Loss 0.967
# [ 56] Train Accuracy: 0.930  	  Train Loss: 0.399 	 Val. Accuracy 0.795 	 Val. Loss 0.961
# [ 57] Train Accuracy: 0.932  	  Train Loss: 0.394 	 Val. Accuracy 0.843 	 Val. Loss 0.702
# [ 58] Train Accuracy: 0.931  	  Train Loss: 0.395 	 Val. Accuracy 0.794 	 Val. Loss 0.945
# [ 59] Train Accuracy: 0.934  	  Train Loss: 0.390 	 Val. Accuracy 0.830 	 Val. Loss 0.787
# [ 60] Train Accuracy: 0.932  	  Train Loss: 0.394 	 Val. Accuracy 0.801 	 Val. Loss 0.852
# [ 61] Train Accuracy: 0.935  	  Train Loss: 0.388 	 Val. Accuracy 0.723 	 Val. Loss 1.268
# [ 62] Train Accuracy: 0.933  	  Train Loss: 0.392 	 Val. Accuracy 0.833 	 Val. Loss 0.722
# [ 63] Train Accuracy: 0.936  	  Train Loss: 0.386 	 Val. Accuracy 0.863 	 Val. Loss 0.647
# [ 64] Train Accuracy: 0.935  	  Train Loss: 0.388 	 Val. Accuracy 0.830 	 Val. Loss 0.842
# [ 65] Train Accuracy: 0.935  	  Train Loss: 0.392 	 Val. Accuracy 0.787 	 Val. Loss 1.010
# [ 66] Train Accuracy: 0.933  	  Train Loss: 0.393 	 Val. Accuracy 0.782 	 Val. Loss 1.057
# [ 67] Train Accuracy: 0.936  	  Train Loss: 0.383 	 Val. Accuracy 0.799 	 Val. Loss 0.994
# [ 68] Train Accuracy: 0.936  	  Train Loss: 0.386 	 Val. Accuracy 0.804 	 Val. Loss 0.915
# [ 69] Train Accuracy: 0.935  	  Train Loss: 0.386 	 Val. Accuracy 0.803 	 Val. Loss 0.898
# [ 70] Train Accuracy: 0.938  	  Train Loss: 0.381 	 Val. Accuracy 0.786 	 Val. Loss 0.992
# [ 71] Train Accuracy: 0.938  	  Train Loss: 0.383 	 Val. Accuracy 0.790 	 Val. Loss 1.024
# [ 72] Train Accuracy: 0.936  	  Train Loss: 0.387 	 Val. Accuracy 0.783 	 Val. Loss 0.978
# [ 73] Train Accuracy: 0.937  	  Train Loss: 0.386 	 Val. Accuracy 0.777 	 Val. Loss 1.016
# [ 74] Train Accuracy: 0.939  	  Train Loss: 0.380 	 Val. Accuracy 0.816 	 Val. Loss 0.870
# [ 75] Train Accuracy: 0.941  	  Train Loss: 0.377 	 Val. Accuracy 0.802 	 Val. Loss 0.895
# [ 76] Train Accuracy: 0.941  	  Train Loss: 0.373 	 Val. Accuracy 0.800 	 Val. Loss 0.898
# [ 77] Train Accuracy: 0.938  	  Train Loss: 0.384 	 Val. Accuracy 0.806 	 Val. Loss 0.893
# [ 78] Train Accuracy: 0.939  	  Train Loss: 0.378 	 Val. Accuracy 0.833 	 Val. Loss 0.761
# [ 79] Train Accuracy: 0.940  	  Train Loss: 0.378 	 Val. Accuracy 0.810 	 Val. Loss 0.897
# [ 80] Train Accuracy: 0.941  	  Train Loss: 0.379 	 Val. Accuracy 0.806 	 Val. Loss 0.900
# [ 81] Train Accuracy: 0.941  	  Train Loss: 0.378 	 Val. Accuracy 0.790 	 Val. Loss 0.981
# [ 82] Train Accuracy: 0.940  	  Train Loss: 0.376 	 Val. Accuracy 0.836 	 Val. Loss 0.771
# [ 83] Train Accuracy: 0.942  	  Train Loss: 0.376 	 Val. Accuracy 0.837 	 Val. Loss 0.779
# [ 84] Train Accuracy: 0.940  	  Train Loss: 0.381 	 Val. Accuracy 0.711 	 Val. Loss 1.425
# [ 85] Train Accuracy: 0.940  	  Train Loss: 0.379 	 Val. Accuracy 0.845 	 Val. Loss 0.756
# [ 86] Train Accuracy: 0.942  	  Train Loss: 0.374 	 Val. Accuracy 0.837 	 Val. Loss 0.779
# [ 87] Train Accuracy: 0.941  	  Train Loss: 0.378 	 Val. Accuracy 0.816 	 Val. Loss 0.845
# [ 88] Train Accuracy: 0.942  	  Train Loss: 0.375 	 Val. Accuracy 0.834 	 Val. Loss 0.746
# [ 89] Train Accuracy: 0.941  	  Train Loss: 0.377 	 Val. Accuracy 0.762 	 Val. Loss 1.147
# [ 90] Train Accuracy: 0.946  	  Train Loss: 0.365 	 Val. Accuracy 0.826 	 Val. Loss 0.851
# [ 91] Train Accuracy: 0.971  	  Train Loss: 0.298 	 Val. Accuracy 0.888 	 Val. Loss 0.610
# [ 92] Train Accuracy: 0.979  	  Train Loss: 0.275 	 Val. Accuracy 0.898 	 Val. Loss 0.566
# [ 93] Train Accuracy: 0.980  	  Train Loss: 0.268 	 Val. Accuracy 0.900 	 Val. Loss 0.558
# [ 94] Train Accuracy: 0.984  	  Train Loss: 0.257 	 Val. Accuracy 0.902 	 Val. Loss 0.559
# [ 95] Train Accuracy: 0.984  	  Train Loss: 0.254 	 Val. Accuracy 0.905 	 Val. Loss 0.547
# [ 96] Train Accuracy: 0.986  	  Train Loss: 0.248 	 Val. Accuracy 0.906 	 Val. Loss 0.533
# [ 97] Train Accuracy: 0.987  	  Train Loss: 0.243 	 Val. Accuracy 0.906 	 Val. Loss 0.548
# [ 98] Train Accuracy: 0.989  	  Train Loss: 0.238 	 Val. Accuracy 0.907 	 Val. Loss 0.545
# [ 99] Train Accuracy: 0.989  	  Train Loss: 0.236 	 Val. Accuracy 0.908 	 Val. Loss 0.560
# [100] Train Accuracy: 0.990  	  Train Loss: 0.233 	 Val. Accuracy 0.907 	 Val. Loss 0.577
# [101] Train Accuracy: 0.990  	  Train Loss: 0.230 	 Val. Accuracy 0.908 	 Val. Loss 0.564
# [102] Train Accuracy: 0.992  	  Train Loss: 0.226 	 Val. Accuracy 0.910 	 Val. Loss 0.548
# [103] Train Accuracy: 0.991  	  Train Loss: 0.225 	 Val. Accuracy 0.908 	 Val. Loss 0.564
# [104] Train Accuracy: 0.992  	  Train Loss: 0.220 	 Val. Accuracy 0.907 	 Val. Loss 0.559
# [105] Train Accuracy: 0.992  	  Train Loss: 0.218 	 Val. Accuracy 0.907 	 Val. Loss 0.582
# [106] Train Accuracy: 0.992  	  Train Loss: 0.217 	 Val. Accuracy 0.910 	 Val. Loss 0.573
# [107] Train Accuracy: 0.992  	  Train Loss: 0.216 	 Val. Accuracy 0.907 	 Val. Loss 0.596
# [108] Train Accuracy: 0.993  	  Train Loss: 0.212 	 Val. Accuracy 0.911 	 Val. Loss 0.581
# [109] Train Accuracy: 0.993  	  Train Loss: 0.210 	 Val. Accuracy 0.907 	 Val. Loss 0.576
# [110] Train Accuracy: 0.994  	  Train Loss: 0.208 	 Val. Accuracy 0.910 	 Val. Loss 0.564
# [111] Train Accuracy: 0.994  	  Train Loss: 0.207 	 Val. Accuracy 0.910 	 Val. Loss 0.576
# [112] Train Accuracy: 0.994  	  Train Loss: 0.205 	 Val. Accuracy 0.909 	 Val. Loss 0.588
# [113] Train Accuracy: 0.994  	  Train Loss: 0.203 	 Val. Accuracy 0.911 	 Val. Loss 0.571
# [114] Train Accuracy: 0.994  	  Train Loss: 0.201 	 Val. Accuracy 0.907 	 Val. Loss 0.585
# [115] Train Accuracy: 0.995  	  Train Loss: 0.199 	 Val. Accuracy 0.912 	 Val. Loss 0.575
# [116] Train Accuracy: 0.994  	  Train Loss: 0.198 	 Val. Accuracy 0.909 	 Val. Loss 0.570
# [117] Train Accuracy: 0.994  	  Train Loss: 0.196 	 Val. Accuracy 0.907 	 Val. Loss 0.581
# [118] Train Accuracy: 0.995  	  Train Loss: 0.195 	 Val. Accuracy 0.909 	 Val. Loss 0.579
# [119] Train Accuracy: 0.995  	  Train Loss: 0.192 	 Val. Accuracy 0.908 	 Val. Loss 0.590
# [120] Train Accuracy: 0.995  	  Train Loss: 0.192 	 Val. Accuracy 0.909 	 Val. Loss 0.582
# [121] Train Accuracy: 0.996  	  Train Loss: 0.189 	 Val. Accuracy 0.909 	 Val. Loss 0.609
# [122] Train Accuracy: 0.995  	  Train Loss: 0.188 	 Val. Accuracy 0.912 	 Val. Loss 0.588
# [123] Train Accuracy: 0.996  	  Train Loss: 0.187 	 Val. Accuracy 0.907 	 Val. Loss 0.592
# [124] Train Accuracy: 0.995  	  Train Loss: 0.187 	 Val. Accuracy 0.907 	 Val. Loss 0.577
# [125] Train Accuracy: 0.996  	  Train Loss: 0.184 	 Val. Accuracy 0.910 	 Val. Loss 0.584
# [126] Train Accuracy: 0.996  	  Train Loss: 0.183 	 Val. Accuracy 0.907 	 Val. Loss 0.593
# [127] Train Accuracy: 0.996  	  Train Loss: 0.181 	 Val. Accuracy 0.911 	 Val. Loss 0.577
# [128] Train Accuracy: 0.996  	  Train Loss: 0.180 	 Val. Accuracy 0.907 	 Val. Loss 0.590
# [129] Train Accuracy: 0.996  	  Train Loss: 0.179 	 Val. Accuracy 0.910 	 Val. Loss 0.595
# [130] Train Accuracy: 0.996  	  Train Loss: 0.177 	 Val. Accuracy 0.907 	 Val. Loss 0.617
# [131] Train Accuracy: 0.996  	  Train Loss: 0.176 	 Val. Accuracy 0.910 	 Val. Loss 0.593
# [132] Train Accuracy: 0.996  	  Train Loss: 0.175 	 Val. Accuracy 0.906 	 Val. Loss 0.598
# [133] Train Accuracy: 0.996  	  Train Loss: 0.175 	 Val. Accuracy 0.911 	 Val. Loss 0.585
# [134] Train Accuracy: 0.997  	  Train Loss: 0.172 	 Val. Accuracy 0.909 	 Val. Loss 0.599
# [135] Train Accuracy: 0.997  	  Train Loss: 0.170 	 Val. Accuracy 0.910 	 Val. Loss 0.578
# [136] Train Accuracy: 0.997  	  Train Loss: 0.169 	 Val. Accuracy 0.909 	 Val. Loss 0.597
# [137] Train Accuracy: 0.997  	  Train Loss: 0.169 	 Val. Accuracy 0.913 	 Val. Loss 0.580
# [138] Train Accuracy: 0.998  	  Train Loss: 0.168 	 Val. Accuracy 0.913 	 Val. Loss 0.576
# [139] Train Accuracy: 0.997  	  Train Loss: 0.168 	 Val. Accuracy 0.913 	 Val. Loss 0.576
# [140] Train Accuracy: 0.998  	  Train Loss: 0.167 	 Val. Accuracy 0.914 	 Val. Loss 0.575
# [141] Train Accuracy: 0.997  	  Train Loss: 0.167 	 Val. Accuracy 0.914 	 Val. Loss 0.577
# [142] Train Accuracy: 0.998  	  Train Loss: 0.167 	 Val. Accuracy 0.913 	 Val. Loss 0.578
# [143] Train Accuracy: 0.998  	  Train Loss: 0.166 	 Val. Accuracy 0.912 	 Val. Loss 0.577
# [144] Train Accuracy: 0.998  	  Train Loss: 0.167 	 Val. Accuracy 0.912 	 Val. Loss 0.579
# [145] Train Accuracy: 0.997  	  Train Loss: 0.167 	 Val. Accuracy 0.912 	 Val. Loss 0.577
# [146] Train Accuracy: 0.998  	  Train Loss: 0.166 	 Val. Accuracy 0.912 	 Val. Loss 0.573
# [147] Train Accuracy: 0.998  	  Train Loss: 0.165 	 Val. Accuracy 0.912 	 Val. Loss 0.575
# [148] Train Accuracy: 0.998  	  Train Loss: 0.166 	 Val. Accuracy 0.912 	 Val. Loss 0.577
# [149] Train Accuracy: 0.998  	  Train Loss: 0.165 	 Val. Accuracy 0.912 	 Val. Loss 0.576
# [150] Train Accuracy: 0.998  	  Train Loss: 0.165 	 Val. Accuracy 0.912 	 Val. Loss 0.575
# [151] Train Accuracy: 0.998  	  Train Loss: 0.164 	 Val. Accuracy 0.911 	 Val. Loss 0.576
# [152] Train Accuracy: 0.998  	  Train Loss: 0.165 	 Val. Accuracy 0.911 	 Val. Loss 0.579
# [153] Train Accuracy: 0.998  	  Train Loss: 0.165 	 Val. Accuracy 0.911 	 Val. Loss 0.578
# [154] Train Accuracy: 0.998  	  Train Loss: 0.165 	 Val. Accuracy 0.911 	 Val. Loss 0.578
# [155] Train Accuracy: 0.998  	  Train Loss: 0.164 	 Val. Accuracy 0.911 	 Val. Loss 0.576
# [156] Train Accuracy: 0.998  	  Train Loss: 0.165 	 Val. Accuracy 0.912 	 Val. Loss 0.578
# [157] Train Accuracy: 0.998  	  Train Loss: 0.164 	 Val. Accuracy 0.911 	 Val. Loss 0.580
# [158] Train Accuracy: 0.998  	  Train Loss: 0.164 	 Val. Accuracy 0.911 	 Val. Loss 0.581
# [159] Train Accuracy: 0.998  	  Train Loss: 0.164 	 Val. Accuracy 0.913 	 Val. Loss 0.581
# [160] Train Accuracy: 0.998  	  Train Loss: 0.164 	 Val. Accuracy 0.913 	 Val. Loss 0.580
# [161] Train Accuracy: 0.998  	  Train Loss: 0.163 	 Val. Accuracy 0.912 	 Val. Loss 0.579
# [162] Train Accuracy: 0.998  	  Train Loss: 0.163 	 Val. Accuracy 0.912 	 Val. Loss 0.579
# [163] Train Accuracy: 0.998  	  Train Loss: 0.163 	 Val. Accuracy 0.912 	 Val. Loss 0.579
# [164] Train Accuracy: 0.998  	  Train Loss: 0.164 	 Val. Accuracy 0.912 	 Val. Loss 0.577
# [165] Train Accuracy: 0.998  	  Train Loss: 0.163 	 Val. Accuracy 0.913 	 Val. Loss 0.577
# [166] Train Accuracy: 0.998  	  Train Loss: 0.163 	 Val. Accuracy 0.911 	 Val. Loss 0.576
# [167] Train Accuracy: 0.998  	  Train Loss: 0.163 	 Val. Accuracy 0.911 	 Val. Loss 0.577
# [168] Train Accuracy: 0.998  	  Train Loss: 0.163 	 Val. Accuracy 0.912 	 Val. Loss 0.577
# [169] Train Accuracy: 0.998  	  Train Loss: 0.163 	 Val. Accuracy 0.911 	 Val. Loss 0.578
# [170] Train Accuracy: 0.998  	  Train Loss: 0.162 	 Val. Accuracy 0.911 	 Val. Loss 0.577
# [171] Train Accuracy: 0.998  	  Train Loss: 0.162 	 Val. Accuracy 0.913 	 Val. Loss 0.576
# [172] Train Accuracy: 0.998  	  Train Loss: 0.162 	 Val. Accuracy 0.912 	 Val. Loss 0.578
# [173] Train Accuracy: 0.998  	  Train Loss: 0.161 	 Val. Accuracy 0.912 	 Val. Loss 0.579
# [174] Train Accuracy: 0.998  	  Train Loss: 0.162 	 Val. Accuracy 0.913 	 Val. Loss 0.579
# [175] Train Accuracy: 0.998  	  Train Loss: 0.162 	 Val. Accuracy 0.913 	 Val. Loss 0.578
# [176] Train Accuracy: 0.998  	  Train Loss: 0.161 	 Val. Accuracy 0.913 	 Val. Loss 0.577
# [177] Train Accuracy: 0.999  	  Train Loss: 0.161 	 Val. Accuracy 0.913 	 Val. Loss 0.577
# [178] Train Accuracy: 0.999  	  Train Loss: 0.161 	 Val. Accuracy 0.913 	 Val. Loss 0.578
# [179] Train Accuracy: 0.998  	  Train Loss: 0.161 	 Val. Accuracy 0.913 	 Val. Loss 0.577
# [180] Train Accuracy: 0.998  	  Train Loss: 0.161 	 Val. Accuracy 0.913 	 Val. Loss 0.576
# [181] Train Accuracy: 0.998  	  Train Loss: 0.161 	 Val. Accuracy 0.913 	 Val. Loss 0.576

# %% [markdown]
# ### Resnet 20

# %%
# Batch size
BS = 128

# Start a session
sess = tf.Session()

# Set up training
sess.run(tf.global_variables_initializer())
steps = [32000,48000]
it = 0
lr = 0.1
epoch = 0
last_acc = 0
first_div = False
while it < 64000:
    # Let's shuffle the data every epoch
    len_ = image_train.shape[0]
    np.random.seed(epoch)
    np.random.shuffle(image_train)
    np.random.seed(epoch)
    np.random.shuffle(label_train)
    # Go through the entire dataset once
    accuracy_train, loss_train = [], []
    final = 0
    for i in range(0, image_train.shape[0]-BS+1, BS):
        if it >= 64000:
            break
        if it in steps:
            lr /= 10
            first_div = True
        # Train a single batch
        batch_images, batch_labels = image_train[i:i+BS], label_train[i:i+BS]
        final = i+BS #useful for training last batch
        accuracy_, loss_, _ = sess.run([accuracy, loss, minimizer], feed_dict={inputs: batch_images, labels: batch_labels, is_training:True,learning_rate:lr})
        accuracy_train.append(accuracy_)
        loss_train.append(loss_)
        it+=1
    # train final batch
    if it >= 64000:
        break
    if it in steps:
        lr /= 10
        first_div = True
    batch_images, batch_labels = image_data[final:len_], label_data[final:len_]
    accuracy_, loss_, _ = sess.run([accuracy, loss, minimizer], feed_dict={inputs: batch_images, labels: batch_labels, is_training:True,learning_rate:lr})
    accuracy_train.append(accuracy_)
    loss_train.append(loss_)
    it+=1
    
    # compute validation results
    len_val = image_val.shape[0]
    accuracy_val, loss_val = [], []
    final = 0
    for i in range(0,len_val-BS+1,BS):
        batch_images, batch_labels = image_val[i:i+BS], label_val[i:i+BS]
        final = i+BS
        accuracy_, loss_ = sess.run([accuracy,loss],feed_dict={final_input:batch_images,labels:batch_labels,is_training:False})
        accuracy_val.append(accuracy_)
        loss_val.append(loss_)
    # test final batch
    batch_images, batch_labels = image_val[final:len_val], label_val[final:len_val]
    accuracy_, loss_ = sess.run([accuracy,loss],feed_dict={final_input:batch_images,labels:batch_labels,is_training:False})
    accuracy_val.append(accuracy_)
    loss_val.append(loss_)
    
    last_acc = np.mean(accuracy_train)
    print('[%3d] Train Accuracy: %0.3f  \t  Train Loss: %0.3f \t Val. Accuracy %0.3f \t Val. Loss %.3f '%(epoch, last_acc, np.mean(loss_train),np.mean(accuracy_val),np.mean(loss_val)))
    epoch += 1

print('[%3d] Train Accuracy: %0.3f  \t  Train Loss: %0.3f \t Val. Accuracy %0.3f \t Val. Loss %.3f '%(epoch, last_acc, np.mean(loss_train),np.mean(accuracy_val),np.mean(loss_val)))
# Out:
# [  0] Train Accuracy: 0.431  	  Train Loss: 1.568 	 Val. Accuracy 0.136 	 Val. Loss 5.716
# [  1] Train Accuracy: 0.620  	  Train Loss: 1.111 	 Val. Accuracy 0.181 	 Val. Loss 18.423
# [  2] Train Accuracy: 0.701  	  Train Loss: 0.910 	 Val. Accuracy 0.433 	 Val. Loss 4.424
# [  3] Train Accuracy: 0.745  	  Train Loss: 0.800 	 Val. Accuracy 0.462 	 Val. Loss 4.034
# [  4] Train Accuracy: 0.773  	  Train Loss: 0.724 	 Val. Accuracy 0.591 	 Val. Loss 2.656
# [  5] Train Accuracy: 0.795  	  Train Loss: 0.676 	 Val. Accuracy 0.640 	 Val. Loss 1.278
# [  6] Train Accuracy: 0.809  	  Train Loss: 0.642 	 Val. Accuracy 0.474 	 Val. Loss 2.757
# [  7] Train Accuracy: 0.821  	  Train Loss: 0.609 	 Val. Accuracy 0.634 	 Val. Loss 1.387
# [  8] Train Accuracy: 0.830  	  Train Loss: 0.587 	 Val. Accuracy 0.575 	 Val. Loss 1.974
# [  9] Train Accuracy: 0.838  	  Train Loss: 0.568 	 Val. Accuracy 0.596 	 Val. Loss 1.514
# [ 10] Train Accuracy: 0.845  	  Train Loss: 0.551 	 Val. Accuracy 0.696 	 Val. Loss 1.116
# [ 11] Train Accuracy: 0.847  	  Train Loss: 0.547 	 Val. Accuracy 0.755 	 Val. Loss 0.885
# [ 12] Train Accuracy: 0.858  	  Train Loss: 0.528 	 Val. Accuracy 0.671 	 Val. Loss 1.222
# [ 13] Train Accuracy: 0.861  	  Train Loss: 0.520 	 Val. Accuracy 0.664 	 Val. Loss 1.347
# [ 14] Train Accuracy: 0.865  	  Train Loss: 0.509 	 Val. Accuracy 0.728 	 Val. Loss 1.087
# [ 15] Train Accuracy: 0.869  	  Train Loss: 0.504 	 Val. Accuracy 0.676 	 Val. Loss 1.296
# [ 16] Train Accuracy: 0.871  	  Train Loss: 0.499 	 Val. Accuracy 0.624 	 Val. Loss 1.535
# [ 17] Train Accuracy: 0.874  	  Train Loss: 0.490 	 Val. Accuracy 0.795 	 Val. Loss 0.761
# [ 18] Train Accuracy: 0.878  	  Train Loss: 0.481 	 Val. Accuracy 0.777 	 Val. Loss 0.806
# [ 19] Train Accuracy: 0.880  	  Train Loss: 0.479 	 Val. Accuracy 0.764 	 Val. Loss 0.920
# [ 20] Train Accuracy: 0.882  	  Train Loss: 0.472 	 Val. Accuracy 0.798 	 Val. Loss 0.758
# [ 21] Train Accuracy: 0.886  	  Train Loss: 0.464 	 Val. Accuracy 0.643 	 Val. Loss 1.439
# [ 22] Train Accuracy: 0.888  	  Train Loss: 0.460 	 Val. Accuracy 0.716 	 Val. Loss 1.229
# [ 23] Train Accuracy: 0.891  	  Train Loss: 0.456 	 Val. Accuracy 0.741 	 Val. Loss 1.116
# [ 24] Train Accuracy: 0.890  	  Train Loss: 0.458 	 Val. Accuracy 0.754 	 Val. Loss 0.948
# [ 25] Train Accuracy: 0.896  	  Train Loss: 0.449 	 Val. Accuracy 0.777 	 Val. Loss 0.857
# [ 26] Train Accuracy: 0.898  	  Train Loss: 0.442 	 Val. Accuracy 0.779 	 Val. Loss 0.866
# [ 27] Train Accuracy: 0.897  	  Train Loss: 0.448 	 Val. Accuracy 0.767 	 Val. Loss 0.909
# [ 28] Train Accuracy: 0.898  	  Train Loss: 0.445 	 Val. Accuracy 0.781 	 Val. Loss 0.872
# [ 29] Train Accuracy: 0.903  	  Train Loss: 0.436 	 Val. Accuracy 0.786 	 Val. Loss 0.845
# [ 30] Train Accuracy: 0.900  	  Train Loss: 0.441 	 Val. Accuracy 0.776 	 Val. Loss 0.866
# [ 31] Train Accuracy: 0.903  	  Train Loss: 0.432 	 Val. Accuracy 0.714 	 Val. Loss 1.264
# [ 32] Train Accuracy: 0.903  	  Train Loss: 0.431 	 Val. Accuracy 0.685 	 Val. Loss 1.374
# [ 33] Train Accuracy: 0.905  	  Train Loss: 0.429 	 Val. Accuracy 0.832 	 Val. Loss 0.701
# [ 34] Train Accuracy: 0.906  	  Train Loss: 0.425 	 Val. Accuracy 0.776 	 Val. Loss 0.904
# [ 35] Train Accuracy: 0.908  	  Train Loss: 0.423 	 Val. Accuracy 0.784 	 Val. Loss 0.862
# [ 36] Train Accuracy: 0.908  	  Train Loss: 0.422 	 Val. Accuracy 0.739 	 Val. Loss 1.119
# [ 37] Train Accuracy: 0.908  	  Train Loss: 0.426 	 Val. Accuracy 0.742 	 Val. Loss 1.140
# [ 38] Train Accuracy: 0.909  	  Train Loss: 0.418 	 Val. Accuracy 0.773 	 Val. Loss 0.955
# [ 39] Train Accuracy: 0.909  	  Train Loss: 0.421 	 Val. Accuracy 0.694 	 Val. Loss 1.254
# [ 40] Train Accuracy: 0.911  	  Train Loss: 0.423 	 Val. Accuracy 0.781 	 Val. Loss 0.860
# [ 41] Train Accuracy: 0.911  	  Train Loss: 0.421 	 Val. Accuracy 0.826 	 Val. Loss 0.710
# [ 42] Train Accuracy: 0.912  	  Train Loss: 0.417 	 Val. Accuracy 0.794 	 Val. Loss 0.818
# [ 43] Train Accuracy: 0.914  	  Train Loss: 0.415 	 Val. Accuracy 0.784 	 Val. Loss 0.853
# [ 44] Train Accuracy: 0.914  	  Train Loss: 0.413 	 Val. Accuracy 0.793 	 Val. Loss 0.875
# [ 45] Train Accuracy: 0.916  	  Train Loss: 0.409 	 Val. Accuracy 0.752 	 Val. Loss 1.055
# [ 46] Train Accuracy: 0.917  	  Train Loss: 0.406 	 Val. Accuracy 0.802 	 Val. Loss 0.843
# [ 47] Train Accuracy: 0.914  	  Train Loss: 0.418 	 Val. Accuracy 0.762 	 Val. Loss 1.012
# [ 48] Train Accuracy: 0.919  	  Train Loss: 0.404 	 Val. Accuracy 0.772 	 Val. Loss 0.925
# [ 49] Train Accuracy: 0.915  	  Train Loss: 0.409 	 Val. Accuracy 0.689 	 Val. Loss 1.385
# [ 50] Train Accuracy: 0.919  	  Train Loss: 0.405 	 Val. Accuracy 0.721 	 Val. Loss 1.137
# [ 51] Train Accuracy: 0.917  	  Train Loss: 0.408 	 Val. Accuracy 0.809 	 Val. Loss 0.843
# [ 52] Train Accuracy: 0.918  	  Train Loss: 0.404 	 Val. Accuracy 0.804 	 Val. Loss 0.851
# [ 53] Train Accuracy: 0.919  	  Train Loss: 0.402 	 Val. Accuracy 0.774 	 Val. Loss 1.035
# [ 54] Train Accuracy: 0.920  	  Train Loss: 0.401 	 Val. Accuracy 0.706 	 Val. Loss 1.321
# [ 55] Train Accuracy: 0.920  	  Train Loss: 0.399 	 Val. Accuracy 0.757 	 Val. Loss 0.991
# [ 56] Train Accuracy: 0.920  	  Train Loss: 0.400 	 Val. Accuracy 0.800 	 Val. Loss 0.857
# [ 57] Train Accuracy: 0.921  	  Train Loss: 0.400 	 Val. Accuracy 0.780 	 Val. Loss 0.878
# [ 58] Train Accuracy: 0.921  	  Train Loss: 0.398 	 Val. Accuracy 0.778 	 Val. Loss 0.972
# [ 59] Train Accuracy: 0.923  	  Train Loss: 0.400 	 Val. Accuracy 0.814 	 Val. Loss 0.869
# [ 60] Train Accuracy: 0.921  	  Train Loss: 0.404 	 Val. Accuracy 0.804 	 Val. Loss 0.834
# [ 61] Train Accuracy: 0.922  	  Train Loss: 0.397 	 Val. Accuracy 0.776 	 Val. Loss 0.923
# [ 62] Train Accuracy: 0.923  	  Train Loss: 0.398 	 Val. Accuracy 0.814 	 Val. Loss 0.863
# [ 63] Train Accuracy: 0.924  	  Train Loss: 0.397 	 Val. Accuracy 0.767 	 Val. Loss 1.030
# [ 64] Train Accuracy: 0.926  	  Train Loss: 0.392 	 Val. Accuracy 0.820 	 Val. Loss 0.760
# [ 65] Train Accuracy: 0.927  	  Train Loss: 0.389 	 Val. Accuracy 0.775 	 Val. Loss 0.985
# [ 66] Train Accuracy: 0.925  	  Train Loss: 0.394 	 Val. Accuracy 0.832 	 Val. Loss 0.742
# [ 67] Train Accuracy: 0.925  	  Train Loss: 0.390 	 Val. Accuracy 0.625 	 Val. Loss 1.895
# [ 68] Train Accuracy: 0.923  	  Train Loss: 0.396 	 Val. Accuracy 0.794 	 Val. Loss 0.891
# [ 69] Train Accuracy: 0.925  	  Train Loss: 0.395 	 Val. Accuracy 0.837 	 Val. Loss 0.726
# [ 70] Train Accuracy: 0.927  	  Train Loss: 0.390 	 Val. Accuracy 0.754 	 Val. Loss 1.035
# [ 71] Train Accuracy: 0.927  	  Train Loss: 0.392 	 Val. Accuracy 0.804 	 Val. Loss 0.839
# [ 72] Train Accuracy: 0.927  	  Train Loss: 0.391 	 Val. Accuracy 0.803 	 Val. Loss 0.871
# [ 73] Train Accuracy: 0.926  	  Train Loss: 0.392 	 Val. Accuracy 0.788 	 Val. Loss 0.899
# [ 74] Train Accuracy: 0.928  	  Train Loss: 0.389 	 Val. Accuracy 0.747 	 Val. Loss 1.127
# [ 75] Train Accuracy: 0.928  	  Train Loss: 0.389 	 Val. Accuracy 0.797 	 Val. Loss 0.900
# [ 76] Train Accuracy: 0.927  	  Train Loss: 0.390 	 Val. Accuracy 0.740 	 Val. Loss 1.238
# [ 77] Train Accuracy: 0.928  	  Train Loss: 0.389 	 Val. Accuracy 0.764 	 Val. Loss 1.006
# [ 78] Train Accuracy: 0.930  	  Train Loss: 0.384 	 Val. Accuracy 0.795 	 Val. Loss 0.939
# [ 79] Train Accuracy: 0.928  	  Train Loss: 0.387 	 Val. Accuracy 0.819 	 Val. Loss 0.792
# [ 80] Train Accuracy: 0.930  	  Train Loss: 0.382 	 Val. Accuracy 0.735 	 Val. Loss 1.220
# [ 81] Train Accuracy: 0.931  	  Train Loss: 0.381 	 Val. Accuracy 0.829 	 Val. Loss 0.782
# [ 82] Train Accuracy: 0.930  	  Train Loss: 0.384 	 Val. Accuracy 0.711 	 Val. Loss 1.491
# [ 83] Train Accuracy: 0.929  	  Train Loss: 0.383 	 Val. Accuracy 0.791 	 Val. Loss 0.956
# [ 84] Train Accuracy: 0.929  	  Train Loss: 0.384 	 Val. Accuracy 0.800 	 Val. Loss 0.885
# [ 85] Train Accuracy: 0.931  	  Train Loss: 0.381 	 Val. Accuracy 0.775 	 Val. Loss 1.043
# [ 86] Train Accuracy: 0.931  	  Train Loss: 0.379 	 Val. Accuracy 0.719 	 Val. Loss 1.291
# [ 87] Train Accuracy: 0.929  	  Train Loss: 0.385 	 Val. Accuracy 0.822 	 Val. Loss 0.815
# [ 88] Train Accuracy: 0.928  	  Train Loss: 0.388 	 Val. Accuracy 0.774 	 Val. Loss 1.052
# [ 89] Train Accuracy: 0.931  	  Train Loss: 0.382 	 Val. Accuracy 0.785 	 Val. Loss 0.961
# [ 90] Train Accuracy: 0.932  	  Train Loss: 0.378 	 Val. Accuracy 0.836 	 Val. Loss 0.782
# [ 91] Train Accuracy: 0.959  	  Train Loss: 0.308 	 Val. Accuracy 0.892 	 Val. Loss 0.533
# [ 92] Train Accuracy: 0.966  	  Train Loss: 0.287 	 Val. Accuracy 0.897 	 Val. Loss 0.512
# [ 93] Train Accuracy: 0.971  	  Train Loss: 0.274 	 Val. Accuracy 0.899 	 Val. Loss 0.528
# [ 94] Train Accuracy: 0.972  	  Train Loss: 0.267 	 Val. Accuracy 0.902 	 Val. Loss 0.500
# [ 95] Train Accuracy: 0.976  	  Train Loss: 0.258 	 Val. Accuracy 0.906 	 Val. Loss 0.495
# [ 96] Train Accuracy: 0.976  	  Train Loss: 0.255 	 Val. Accuracy 0.904 	 Val. Loss 0.506
# [ 97] Train Accuracy: 0.978  	  Train Loss: 0.250 	 Val. Accuracy 0.904 	 Val. Loss 0.515
# [ 98] Train Accuracy: 0.978  	  Train Loss: 0.245 	 Val. Accuracy 0.905 	 Val. Loss 0.495
# [ 99] Train Accuracy: 0.980  	  Train Loss: 0.242 	 Val. Accuracy 0.901 	 Val. Loss 0.536
# [100] Train Accuracy: 0.980  	  Train Loss: 0.238 	 Val. Accuracy 0.906 	 Val. Loss 0.501
# [101] Train Accuracy: 0.980  	  Train Loss: 0.237 	 Val. Accuracy 0.908 	 Val. Loss 0.500
# [102] Train Accuracy: 0.981  	  Train Loss: 0.234 	 Val. Accuracy 0.902 	 Val. Loss 0.502
# [103] Train Accuracy: 0.981  	  Train Loss: 0.232 	 Val. Accuracy 0.902 	 Val. Loss 0.526
# [104] Train Accuracy: 0.983  	  Train Loss: 0.226 	 Val. Accuracy 0.908 	 Val. Loss 0.505
# [105] Train Accuracy: 0.983  	  Train Loss: 0.225 	 Val. Accuracy 0.905 	 Val. Loss 0.513
# [106] Train Accuracy: 0.983  	  Train Loss: 0.224 	 Val. Accuracy 0.907 	 Val. Loss 0.494
# [107] Train Accuracy: 0.984  	  Train Loss: 0.220 	 Val. Accuracy 0.904 	 Val. Loss 0.515
# [108] Train Accuracy: 0.984  	  Train Loss: 0.218 	 Val. Accuracy 0.904 	 Val. Loss 0.519
# [109] Train Accuracy: 0.985  	  Train Loss: 0.215 	 Val. Accuracy 0.904 	 Val. Loss 0.520
# [110] Train Accuracy: 0.986  	  Train Loss: 0.211 	 Val. Accuracy 0.899 	 Val. Loss 0.531
# [111] Train Accuracy: 0.985  	  Train Loss: 0.211 	 Val. Accuracy 0.901 	 Val. Loss 0.532
# [112] Train Accuracy: 0.985  	  Train Loss: 0.209 	 Val. Accuracy 0.902 	 Val. Loss 0.543
# [113] Train Accuracy: 0.986  	  Train Loss: 0.207 	 Val. Accuracy 0.903 	 Val. Loss 0.519
# [114] Train Accuracy: 0.987  	  Train Loss: 0.205 	 Val. Accuracy 0.906 	 Val. Loss 0.516
# [115] Train Accuracy: 0.986  	  Train Loss: 0.205 	 Val. Accuracy 0.903 	 Val. Loss 0.526
# [116] Train Accuracy: 0.987  	  Train Loss: 0.202 	 Val. Accuracy 0.905 	 Val. Loss 0.528
# [117] Train Accuracy: 0.988  	  Train Loss: 0.200 	 Val. Accuracy 0.899 	 Val. Loss 0.565
# [118] Train Accuracy: 0.987  	  Train Loss: 0.198 	 Val. Accuracy 0.900 	 Val. Loss 0.555
# [119] Train Accuracy: 0.989  	  Train Loss: 0.195 	 Val. Accuracy 0.902 	 Val. Loss 0.533
# [120] Train Accuracy: 0.988  	  Train Loss: 0.195 	 Val. Accuracy 0.902 	 Val. Loss 0.534
# [121] Train Accuracy: 0.989  	  Train Loss: 0.193 	 Val. Accuracy 0.900 	 Val. Loss 0.542
# [122] Train Accuracy: 0.988  	  Train Loss: 0.192 	 Val. Accuracy 0.900 	 Val. Loss 0.553
# [123] Train Accuracy: 0.989  	  Train Loss: 0.191 	 Val. Accuracy 0.902 	 Val. Loss 0.542
# [124] Train Accuracy: 0.989  	  Train Loss: 0.190 	 Val. Accuracy 0.898 	 Val. Loss 0.565
# [125] Train Accuracy: 0.989  	  Train Loss: 0.187 	 Val. Accuracy 0.899 	 Val. Loss 0.570
# [126] Train Accuracy: 0.989  	  Train Loss: 0.186 	 Val. Accuracy 0.896 	 Val. Loss 0.584
# [127] Train Accuracy: 0.989  	  Train Loss: 0.184 	 Val. Accuracy 0.903 	 Val. Loss 0.544
# [128] Train Accuracy: 0.990  	  Train Loss: 0.183 	 Val. Accuracy 0.904 	 Val. Loss 0.546
# [129] Train Accuracy: 0.989  	  Train Loss: 0.183 	 Val. Accuracy 0.902 	 Val. Loss 0.538
# [130] Train Accuracy: 0.989  	  Train Loss: 0.181 	 Val. Accuracy 0.897 	 Val. Loss 0.583
# [131] Train Accuracy: 0.989  	  Train Loss: 0.180 	 Val. Accuracy 0.887 	 Val. Loss 0.600
# [132] Train Accuracy: 0.990  	  Train Loss: 0.178 	 Val. Accuracy 0.900 	 Val. Loss 0.553
# [133] Train Accuracy: 0.990  	  Train Loss: 0.176 	 Val. Accuracy 0.901 	 Val. Loss 0.543
# [134] Train Accuracy: 0.990  	  Train Loss: 0.176 	 Val. Accuracy 0.904 	 Val. Loss 0.549
# [135] Train Accuracy: 0.990  	  Train Loss: 0.174 	 Val. Accuracy 0.902 	 Val. Loss 0.530
# [136] Train Accuracy: 0.991  	  Train Loss: 0.172 	 Val. Accuracy 0.902 	 Val. Loss 0.536
# [137] Train Accuracy: 0.992  	  Train Loss: 0.169 	 Val. Accuracy 0.904 	 Val. Loss 0.529
# [138] Train Accuracy: 0.992  	  Train Loss: 0.168 	 Val. Accuracy 0.904 	 Val. Loss 0.526
# [139] Train Accuracy: 0.993  	  Train Loss: 0.167 	 Val. Accuracy 0.905 	 Val. Loss 0.527
# [140] Train Accuracy: 0.993  	  Train Loss: 0.167 	 Val. Accuracy 0.904 	 Val. Loss 0.527
# [141] Train Accuracy: 0.993  	  Train Loss: 0.167 	 Val. Accuracy 0.904 	 Val. Loss 0.530
# [142] Train Accuracy: 0.993  	  Train Loss: 0.166 	 Val. Accuracy 0.902 	 Val. Loss 0.532
# [143] Train Accuracy: 0.993  	  Train Loss: 0.166 	 Val. Accuracy 0.903 	 Val. Loss 0.534
# [144] Train Accuracy: 0.994  	  Train Loss: 0.165 	 Val. Accuracy 0.903 	 Val. Loss 0.537
# [145] Train Accuracy: 0.993  	  Train Loss: 0.165 	 Val. Accuracy 0.904 	 Val. Loss 0.535
# [146] Train Accuracy: 0.994  	  Train Loss: 0.165 	 Val. Accuracy 0.904 	 Val. Loss 0.537
# [147] Train Accuracy: 0.993  	  Train Loss: 0.166 	 Val. Accuracy 0.903 	 Val. Loss 0.533
# [148] Train Accuracy: 0.993  	  Train Loss: 0.165 	 Val. Accuracy 0.904 	 Val. Loss 0.534
# [149] Train Accuracy: 0.994  	  Train Loss: 0.164 	 Val. Accuracy 0.903 	 Val. Loss 0.531
# [150] Train Accuracy: 0.993  	  Train Loss: 0.164 	 Val. Accuracy 0.904 	 Val. Loss 0.530
# [151] Train Accuracy: 0.994  	  Train Loss: 0.165 	 Val. Accuracy 0.902 	 Val. Loss 0.533
# [152] Train Accuracy: 0.993  	  Train Loss: 0.165 	 Val. Accuracy 0.903 	 Val. Loss 0.535
# [153] Train Accuracy: 0.994  	  Train Loss: 0.164 	 Val. Accuracy 0.902 	 Val. Loss 0.536
# [154] Train Accuracy: 0.993  	  Train Loss: 0.164 	 Val. Accuracy 0.902 	 Val. Loss 0.537
# [155] Train Accuracy: 0.993  	  Train Loss: 0.165 	 Val. Accuracy 0.901 	 Val. Loss 0.536
# [156] Train Accuracy: 0.993  	  Train Loss: 0.164 	 Val. Accuracy 0.902 	 Val. Loss 0.536
# [157] Train Accuracy: 0.993  	  Train Loss: 0.163 	 Val. Accuracy 0.903 	 Val. Loss 0.538
# [158] Train Accuracy: 0.993  	  Train Loss: 0.163 	 Val. Accuracy 0.901 	 Val. Loss 0.540
# [159] Train Accuracy: 0.994  	  Train Loss: 0.163 	 Val. Accuracy 0.903 	 Val. Loss 0.539
# [160] Train Accuracy: 0.994  	  Train Loss: 0.163 	 Val. Accuracy 0.903 	 Val. Loss 0.539
# [161] Train Accuracy: 0.994  	  Train Loss: 0.162 	 Val. Accuracy 0.904 	 Val. Loss 0.535
# [162] Train Accuracy: 0.994  	  Train Loss: 0.162 	 Val. Accuracy 0.903 	 Val. Loss 0.536
# [163] Train Accuracy: 0.994  	  Train Loss: 0.163 	 Val. Accuracy 0.903 	 Val. Loss 0.536
# [164] Train Accuracy: 0.994  	  Train Loss: 0.162 	 Val. Accuracy 0.902 	 Val. Loss 0.537
# [165] Train Accuracy: 0.994  	  Train Loss: 0.162 	 Val. Accuracy 0.902 	 Val. Loss 0.537
# [166] Train Accuracy: 0.994  	  Train Loss: 0.162 	 Val. Accuracy 0.902 	 Val. Loss 0.538
# [167] Train Accuracy: 0.994  	  Train Loss: 0.161 	 Val. Accuracy 0.902 	 Val. Loss 0.539
# [168] Train Accuracy: 0.994  	  Train Loss: 0.162 	 Val. Accuracy 0.903 	 Val. Loss 0.538
# [169] Train Accuracy: 0.994  	  Train Loss: 0.161 	 Val. Accuracy 0.904 	 Val. Loss 0.539
# [170] Train Accuracy: 0.995  	  Train Loss: 0.161 	 Val. Accuracy 0.902 	 Val. Loss 0.540
# [171] Train Accuracy: 0.994  	  Train Loss: 0.161 	 Val. Accuracy 0.901 	 Val. Loss 0.539
# [172] Train Accuracy: 0.995  	  Train Loss: 0.160 	 Val. Accuracy 0.902 	 Val. Loss 0.540
# [173] Train Accuracy: 0.994  	  Train Loss: 0.161 	 Val. Accuracy 0.902 	 Val. Loss 0.539
# [174] Train Accuracy: 0.995  	  Train Loss: 0.160 	 Val. Accuracy 0.902 	 Val. Loss 0.538
# [175] Train Accuracy: 0.994  	  Train Loss: 0.160 	 Val. Accuracy 0.903 	 Val. Loss 0.536
# [176] Train Accuracy: 0.994  	  Train Loss: 0.160 	 Val. Accuracy 0.902 	 Val. Loss 0.541
# [177] Train Accuracy: 0.994  	  Train Loss: 0.160 	 Val. Accuracy 0.902 	 Val. Loss 0.543
# [178] Train Accuracy: 0.994  	  Train Loss: 0.160 	 Val. Accuracy 0.901 	 Val. Loss 0.543
# [179] Train Accuracy: 0.994  	  Train Loss: 0.161 	 Val. Accuracy 0.901 	 Val. Loss 0.538
# [180] Train Accuracy: 0.994  	  Train Loss: 0.159 	 Val. Accuracy 0.903 	 Val. Loss 0.538
# [181] Train Accuracy: 0.994  	  Train Loss: 0.158 	 Val. Accuracy 0.903 	 Val. Loss 0.538

# %% [markdown]
# ### Save Model

# %%
# Source: CS342 with Dr. Krähenbühl
def save(output_file, graph=None, session=None):
    from zipfile import ZipFile
    from os import path, remove, rmdir
    from tempfile import mkdtemp

    tmp_dir = mkdtemp()
    tmp_output = path.join(tmp_dir, path.basename(output_file))
    with graph.as_default():
        saver = tf.train.Saver(allow_empty=True)
        saver.save(session, tmp_output, write_state=False)

    of = ZipFile(output_file, 'w')
    for f in glob(tmp_output+'.*'):
        of.write(f, path.basename(f))
        remove(f)
    of.close()
    rmdir(tmp_dir)

# %%
graph = tf.get_default_graph()
save('./resnet32_wide2.tfg',graph,sess)

# %% [markdown]
# ### Load Model

# %%
def load(input_file, graph=None, session=None):
    from os import path
    from shutil import rmtree
    from tempfile import mkdtemp
    from zipfile import ZipFile

    tmp_dir = mkdtemp()

    f = ZipFile(input_file, 'r')
    f.extractall(tmp_dir)
    f.close()

    # Find the model name
    meta_files = glob(path.join(tmp_dir, '*.meta'))
    if len(meta_files) < 1:
        raise IOError( "[E] No meta file found, giving up" )
    if len(meta_files) > 1:
        raise IOError( "[E] More than one meta file found, giving up" )

    meta_file = meta_files[0]
    model_file = meta_file.replace('.meta', '')

    if graph is None:
        graph = tf.get_default_graph()
    if session is None:
        session = tf.get_default_session()
    if session is None:
        session = tf.Session()

    # Load the model in TF
    with graph.as_default():
        saver = tf.train.import_meta_graph(meta_file)
        if saver is not None:
            saver.restore(session, model_file)
    rmtree(tmp_dir)
    return graph

# %%
graph = load('./week4_model_temp.tfg')

# %% [markdown]
# ### Make Test Predictions

# %%
test_files = glob('./test/*')
test_files = sorted(test_files, key = lambda x:int(x.split('\\')[1].split('.png')[0]))

# %%
image_test = convert_images(test_files)

# %%
np.save('test.npy',image_test)

# %%
image_test.shape
# Out:
# (300000, 32, 32, 3)

# %%
sess = tf.Session()
with graph.as_default():
    test_batch = 3000 # batch shape
    predictions = []
    for i in range(0,image_test.shape[0],test_batch):
        if i%90000==0:
            print(i)
        batch_images = image_test[i:i+test_batch]
        batch_pred = sess.run(tf.argmax(output, 1), feed_dict = {final_input: batch_images,is_training:False})
        for j in range(test_batch):
            predictions.append(batch_pred[j])

# %%
test_classes = np.asarray([labels_unique[predictions[i]] for i in range(len(predictions))])
test_df = pd.DataFrame(test_classes)
test_df['id'] = pd.Series([i for i in range(1,len(predictions)+1)])
test_df['label'] = test_df[test_df.columns[0]]
test_df = test_df[['id','label']]
test_df

# %%
test_df.to_csv('cnn_week2_temp.csv',index=False)
